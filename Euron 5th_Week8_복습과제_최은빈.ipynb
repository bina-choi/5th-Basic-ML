# %%
# --- 라이브러리 설치 ---
# !pip install pycaret
# !pip install markupsafe==2.0.1
# !pip jinja2
# Out:
# Collecting pycaret
#   Downloading pycaret-3.1.0-py3-none-any.whl (483 kB)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\flex\anaconda3\lib\site-packages (from pycaret) (0.13.2)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# Collecting tbats>=1.1.3
#   Downloading tbats-1.1.3-py3-none-any.whl (44 kB)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\flex\anaconda3\lib\site-packages (from pycaret) (4.64.0)
# Requirement already satisfied: pandas<2.0.0,>=1.3.0 in c:\users\flex\anaconda3\lib\site-packages (from pycaret) (1.4.2)
# Collecting yellowbrick>=1.4
#   Downloading yellowbrick-1.5-py3-none-any.whl (282 kB)
# Collecting xxhash
#   Downloading xxhash-3.4.1-cp39-cp39-win_amd64.whl (29 kB)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\flex\anaconda3\lib\site-packages (from pycaret) (7.6.5)
# Collecting kaleido>=0.2.1
#   Downloading kaleido-0.2.1-py2.py3-none-win_amd64.whl (65.9 MB)
# Requirement already satisfied: numba>=0.55.0 in c:\users\flex\anaconda3\lib\site-packages (from pycaret) (0.55.1)
# Collecting importlib-metadata>=4.12.0
#   Downloading importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Collecting pyod>=1.0.8
#   Downloading pyod-1.1.1.tar.gz (159 kB)
# Collecting pmdarima!=1.8.1,<3.0.0,>=1.8.0
#   Downloading pmdarima-2.0.4-cp39-cp39-win_amd64.whl (614 kB)
# Requirement already satisfied: jinja2>=1.2 in c:\users\flex\anaconda3\lib\site-packages (from pycaret) (2.11.3)
# Requirement already satisfied: scikit-learn<1.3.0,>=1.0 in c:\users\flex\anaconda3\lib\site-packages (from pycaret) (1.0.2)
# Collecting psutil>=5.9.0
#   Downloading psutil-5.9.6-cp37-abi3-win_amd64.whl (252 kB)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\flex\anaconda3\lib\site-packages (from pycaret) (3.3.2)
# Collecting scipy~=1.10.1
#   Downloading scipy-1.10.1-cp39-cp39-win_amd64.whl (42.5 MB)
# Requirement already satisfied: cloudpickle in c:\users\flex\anaconda3\lib\site-packages (from pycaret) (2.0.0)
# Requirement already satisfied: numpy<1.24,>=1.21 in c:\users\flex\anaconda3\lib\site-packages (from pycaret) (1.21.5)
# Requirement already satisfied: requests>=2.27.1 in c:\users\flex\anaconda3\lib\site-packages (from pycaret) (2.27.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\flex\anaconda3\lib\site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in c:\users\flex\anaconda3\lib\site-packages (from pycaret) (0.11.0)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\flex\anaconda3\lib\site-packages (from pycaret) (3.5.1)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\flex\anaconda3\lib\site-packages (from pycaret) (2.0.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\flex\anaconda3\lib\site-packages (from pycaret) (5.3.0)
# Collecting category-encoders>=2.4.0
#   Downloading category_encoders-2.6.3-py2.py3-none-any.whl (81 kB)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\flex\anaconda3\lib\site-packages (from pycaret) (8.2.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\flex\anaconda3\lib\site-packages (from pycaret) (5.6.0)
# Collecting sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1
#   Downloading sktime-0.21.1-py3-none-any.whl (17.1 MB)
# Collecting plotly-resampler>=0.8.3.1
#   Downloading plotly_resampler-0.9.1-py3-none-any.whl (73 kB)
# Collecting scikit-plot>=0.3.7
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Collecting deprecation>=2.1.0
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting schemdraw==0.15
#   Downloading schemdraw-0.15-py3-none-any.whl (106 kB)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\flex\anaconda3\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.2)
# Requirement already satisfied: packaging in c:\users\flex\anaconda3\lib\site-packages (from deprecation>=2.1.0->pycaret) (21.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\flex\anaconda3\lib\site-packages (from imbalanced-learn>=0.8.1->pycaret) (2.2.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\flex\anaconda3\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.7.0)
# Requirement already satisfied: matplotlib-inline in c:\users\flex\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.2)
# Requirement already satisfied: decorator in c:\users\flex\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\flex\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (61.2.0)
# Requirement already satisfied: stack-data in c:\users\flex\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: colorama in c:\users\flex\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.4)
# Requirement already satisfied: pickleshare in c:\users\flex\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: traitlets>=5 in c:\users\flex\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\flex\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.20)
# Requirement already satisfied: backcall in c:\users\flex\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\flex\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\flex\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (2.11.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\flex\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\flex\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\flex\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\flex\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (6.9.1)
# Requirement already satisfied: nest-asyncio in c:\users\flex\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.5)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\flex\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\flex\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\flex\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1.12)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\flex\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\flex\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\flex\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\flex\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (4.9.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\flex\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (302)
# Requirement already satisfied: wheel in c:\users\flex\anaconda3\lib\site-packages (from lightgbm>=3.0.0->pycaret) (0.37.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\flex\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\flex\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\flex\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\flex\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\flex\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (9.0.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\flex\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.4.0)
# Requirement already satisfied: fastjsonschema in c:\users\flex\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.15.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\flex\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\flex\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.18.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\flex\anaconda3\lib\site-packages (from numba>=0.55.0->pycaret) (0.38.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\flex\anaconda3\lib\site-packages (from pandas<2.0.0,>=1.3.0->pycaret) (2021.3)
# Requirement already satisfied: six in c:\users\flex\anaconda3\lib\site-packages (from patsy>=0.5.1->category-encoders>=2.4.0->pycaret) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\flex\anaconda3\lib\site-packages (from plotly>=5.0.0->pycaret) (8.0.1)
# Collecting dash<3.0.0,>=2.11.0
#   Downloading dash-2.14.1-py3-none-any.whl (10.4 MB)
# Collecting trace-updater>=0.0.8
#   Downloading trace_updater-0.0.9.1-py3-none-any.whl (185 kB)
# Collecting tsdownsample==0.1.2
#   Downloading tsdownsample-0.1.2-cp39-none-win_amd64.whl (1.0 MB)
# Collecting orjson<4.0.0,>=3.8.0
#   Downloading orjson-3.9.10-cp39-none-win_amd64.whl (134 kB)
# Collecting ansi2html
#   Downloading ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\flex\anaconda3\lib\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.3)
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\flex\anaconda3\lib\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.1.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\flex\anaconda3\lib\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (4.1.1)
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting retrying
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\flex\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.1)
# Requirement already satisfied: click>=5.1 in c:\users\flex\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (8.0.4)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\flex\anaconda3\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (0.29.28)
# Requirement already satisfied: urllib3 in c:\users\flex\anaconda3\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (1.26.9)
# Requirement already satisfied: wcwidth in c:\users\flex\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\flex\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\flex\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\flex\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Collecting deprecated>=1.2.13
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting scikit-base<0.6.0
#   Downloading scikit_base-0.5.2-py3-none-any.whl (118 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\flex\anaconda3\lib\site-packages (from deprecated>=1.2.13->sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret) (1.12.1)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\flex\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.4.8)
# Requirement already satisfied: argon2-cffi in c:\users\flex\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\flex\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: prometheus-client in c:\users\flex\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.13.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\flex\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.13.1)
# Requirement already satisfied: nbconvert in c:\users\flex\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.4.4)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\flex\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\flex\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\flex\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\flex\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.21)
# Requirement already satisfied: beautifulsoup4 in c:\users\flex\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.11.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\flex\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.4)
# Requirement already satisfied: defusedxml in c:\users\flex\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\flex\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.13)
# Requirement already satisfied: jupyterlab-pygments in c:\users\flex\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: bleach in c:\users\flex\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.1.0)
# Requirement already satisfied: testpath in c:\users\flex\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\flex\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\flex\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.5.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\flex\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\flex\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Requirement already satisfied: executing in c:\users\flex\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\flex\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\flex\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Building wheels for collected packages: pyod
#   Building wheel for pyod (setup.py): started
#   Building wheel for pyod (setup.py): finished with status 'done'
#   Created wheel for pyod: filename=pyod-1.1.1-py3-none-any.whl size=190097 sha256=1bd2c029f6d664cdb7912a17e0146ef8c86cd6eac37134c4eb3404e1337eec83
#   Stored in directory: c:\users\flex\appdata\local\pip\cache\wheels\ac\7a\f7\a34ed31640e88f7542deb3b4c46505f5b1e0d74559caa472e8
# Successfully built pyod
# Installing collected packages: scipy, retrying, importlib-metadata, dash-table, dash-html-components, dash-core-components, ansi2html, tsdownsample, trace-updater, scikit-base, pmdarima, orjson, deprecated, dash, yellowbrick, xxhash, tbats, sktime, scikit-plot, schemdraw, pyod, psutil, plotly-resampler, kaleido, deprecation, category-encoders, pycaret
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.11.3
#     Uninstalling importlib-metadata-4.11.3:
#       Successfully uninstalled importlib-metadata-4.11.3
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.8.0
#     Uninstalling psutil-5.8.0:
#       Successfully uninstalled psutil-5.8.0
# Successfully installed ansi2html-1.8.0 category-encoders-2.6.3 dash-2.14.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 deprecated-1.2.14 deprecation-2.1.0 importlib-metadata-6.8.0 kaleido-0.2.1 orjson-3.9.10 plotly-resampler-0.9.1 pmdarima-2.0.4 psutil-5.9.6 pycaret-3.1.0 pyod-1.1.1 retrying-1.3.4 schemdraw-0.15 scikit-base-0.5.2 scikit-plot-0.3.7 scipy-1.10.1 sktime-0.21.1 tbats-1.1.3 trace-updater-0.0.9.1 tsdownsample-0.1.2 xxhash-3.4.1 yellowbrick-1.5
# Requirement already satisfied: markupsafe==2.0.1 in c:\users\flex\anaconda3\lib\site-packages (2.0.1)
# ERROR: unknown command "jinja2"

# %%
# --- 라이브러리 import ---
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import pycaret
import warnings
import jinja2

from sklearn.preprocessing import LabelEncoder
from scipy import stats
from scipy.stats import *
from pycaret.regression import *

# --- 라이브러리 세팅 ---
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')
plt.rcParams['figure.dpi'] = 100

# %%
# --- Create List of Color Palletes ---
olive_grad = ['#2A3F07', '#557F0F', '#7FBE17', '#A4E637', '#C1EE76']
yellow_grad = ['#413D05', '#837A0B', '#C5B710', '#E8DA2E', '#F9EE6A']
color_mix = ['#356211', '#6C8F32', '#F2E880', '#C15C37', '#AA471F']
black_grad = ['#100C07', '#3E3B39', '#6D6A6A', '#9B9A9C', '#CAC9CD']

# --- Plot Color Palletes --
sns.palplot(olive_grad)
sns.palplot(yellow_grad)
sns.palplot(color_mix)
sns.palplot(black_grad)

# %%
#데이터셋 불러오기
ds = pd.read_csv("C:/Users/Flex/Documents/Euron/avocado.csv")
ds.head().style.background_gradient(cmap='Greens').set_properties(**{'font-family': 'Segoe UI'}).hide_index()
# Out:
# <style type="text/css">
# #T_52194_row0_col0, #T_52194_row0_col6, #T_52194_row0_col9, #T_52194_row0_col10, #T_52194_row0_col12, #T_52194_row1_col4, #T_52194_row1_col10, #T_52194_row1_col12, #T_52194_row2_col2, #T_52194_row2_col10, #T_52194_row2_col12, #T_52194_row3_col7, #T_52194_row3_col8, #T_52194_row3_col10, #T_52194_row3_col12, #T_52194_row4_col3, #T_52194_row4_col5, #T_52194_row4_col10, #T_52194_row4_col12 {
#   background-color: #f7fcf5;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_52194_row0_col1, #T_52194_row0_col11, #T_52194_row0_col13, #T_52194_row1_col1, #T_52194_row1_col11, #T_52194_row1_col13, #T_52194_row2_col1, #T_52194_row2_col11, #T_52194_row2_col13, #T_52194_row3_col1, #T_52194_row3_col11, #T_52194_row3_col13, #T_52194_row4_col1, #T_52194_row4_col11, #T_52194_row4_col13 {
#   font-family: Segoe UI;
# }
# #T_52194_row0_col2 {
#   background-color: #005321;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_52194_row0_col3 {
#   background-color: #d4eece;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_52194_row0_col4 {
#   background-color: #17813d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_52194_row0_col5 {
#   background-color: #dcf2d7;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_52194_row0_col7 {
#   background-color: #1a843f;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_52194_row0_col8 {
#   background-color: #19833e;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_52194_row1_col0 {
#   background-color: #c7e9c0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_52194_row1_col2, #T_52194_row1_col7, #T_52194_row1_col8, #T_52194_row2_col3, #T_52194_row2_col5, #T_52194_row2_col6, #T_52194_row3_col4, #T_52194_row4_col0, #T_52194_row4_col9 {
#   background-color: #00441b;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_52194_row1_col3 {
#   background-color: #eff9ec;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_52194_row1_col5 {
#   background-color: #f5fbf3;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_52194_row1_col6 {
#   background-color: #e5f5e1;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_52194_row1_col9 {
#   background-color: #f1faee;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_52194_row2_col0 {
#   background-color: #73c476;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_52194_row2_col4 {
#   background-color: #c3e7bc;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_52194_row2_col7 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_52194_row2_col8 {
#   background-color: #3fa85b;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_52194_row2_col9, #T_52194_row4_col7 {
#   background-color: #e9f7e5;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_52194_row3_col0 {
#   background-color: #228a44;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_52194_row3_col2 {
#   background-color: #a7dba0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_52194_row3_col3 {
#   background-color: #92d28f;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_52194_row3_col5 {
#   background-color: #8dd08a;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_52194_row3_col6 {
#   background-color: #bae3b3;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_52194_row3_col9 {
#   background-color: #9cd797;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_52194_row4_col2 {
#   background-color: #0b7734;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_52194_row4_col4 {
#   background-color: #52b365;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_52194_row4_col6 {
#   background-color: #aedea7;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_52194_row4_col8 {
#   background-color: #ebf7e7;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_52194">
#   <thead>
#     <tr>
#       <th id="T_52194_level0_col0" class="col_heading level0 col0" >Unnamed: 0</th>
#       <th id="T_52194_level0_col1" class="col_heading level0 col1" >Date</th>
#       <th id="T_52194_level0_col2" class="col_heading level0 col2" >AveragePrice</th>
#       <th id="T_52194_level0_col3" class="col_heading level0 col3" >Total Volume</th>
#       <th id="T_52194_level0_col4" class="col_heading level0 col4" >4046</th>
#       <th id="T_52194_level0_col5" class="col_heading level0 col5" >4225</th>
#       <th id="T_52194_level0_col6" class="col_heading level0 col6" >4770</th>
#       <th id="T_52194_level0_col7" class="col_heading level0 col7" >Total Bags</th>
#       <th id="T_52194_level0_col8" class="col_heading level0 col8" >Small Bags</th>
#       <th id="T_52194_level0_col9" class="col_heading level0 col9" >Large Bags</th>
#       <th id="T_52194_level0_col10" class="col_heading level0 col10" >XLarge Bags</th>
#       <th id="T_52194_level0_col11" class="col_heading level0 col11" >type</th>
#       <th id="T_52194_level0_col12" class="col_heading level0 col12" >year</th>
#       <th id="T_52194_level0_col13" class="col_heading level0 col13" >region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_52194_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_52194_row0_col1" class="data row0 col1" >2015-12-27</td>
#       <td id="T_52194_row0_col2" class="data row0 col2" >1.330000</td>
#       <td id="T_52194_row0_col3" class="data row0 col3" >64236.620000</td>
#       <td id="T_52194_row0_col4" class="data row0 col4" >1036.740000</td>
#       <td id="T_52194_row0_col5" class="data row0 col5" >54454.850000</td>
#       <td id="T_52194_row0_col6" class="data row0 col6" >48.160000</td>
#       <td id="T_52194_row0_col7" class="data row0 col7" >8696.870000</td>
#       <td id="T_52194_row0_col8" class="data row0 col8" >8603.620000</td>
#       <td id="T_52194_row0_col9" class="data row0 col9" >93.250000</td>
#       <td id="T_52194_row0_col10" class="data row0 col10" >0.000000</td>
#       <td id="T_52194_row0_col11" class="data row0 col11" >conventional</td>
#       <td id="T_52194_row0_col12" class="data row0 col12" >2015</td>
#       <td id="T_52194_row0_col13" class="data row0 col13" >Albany</td>
#     </tr>
#     <tr>
#       <td id="T_52194_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_52194_row1_col1" class="data row1 col1" >2015-12-20</td>
#       <td id="T_52194_row1_col2" class="data row1 col2" >1.350000</td>
#       <td id="T_52194_row1_col3" class="data row1 col3" >54876.980000</td>
#       <td id="T_52194_row1_col4" class="data row1 col4" >674.280000</td>
#       <td id="T_52194_row1_col5" class="data row1 col5" >44638.810000</td>
#       <td id="T_52194_row1_col6" class="data row1 col6" >58.330000</td>
#       <td id="T_52194_row1_col7" class="data row1 col7" >9505.560000</td>
#       <td id="T_52194_row1_col8" class="data row1 col8" >9408.070000</td>
#       <td id="T_52194_row1_col9" class="data row1 col9" >97.490000</td>
#       <td id="T_52194_row1_col10" class="data row1 col10" >0.000000</td>
#       <td id="T_52194_row1_col11" class="data row1 col11" >conventional</td>
#       <td id="T_52194_row1_col12" class="data row1 col12" >2015</td>
#       <td id="T_52194_row1_col13" class="data row1 col13" >Albany</td>
#     </tr>
#     <tr>
#       <td id="T_52194_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_52194_row2_col1" class="data row2 col1" >2015-12-13</td>
#       <td id="T_52194_row2_col2" class="data row2 col2" >0.930000</td>
#       <td id="T_52194_row2_col3" class="data row2 col3" >118220.220000</td>
#       <td id="T_52194_row2_col4" class="data row2 col4" >794.700000</td>
#       <td id="T_52194_row2_col5" class="data row2 col5" >109149.670000</td>
#       <td id="T_52194_row2_col6" class="data row2 col6" >130.500000</td>
#       <td id="T_52194_row2_col7" class="data row2 col7" >8145.350000</td>
#       <td id="T_52194_row2_col8" class="data row2 col8" >8042.210000</td>
#       <td id="T_52194_row2_col9" class="data row2 col9" >103.140000</td>
#       <td id="T_52194_row2_col10" class="data row2 col10" >0.000000</td>
#       <td id="T_52194_row2_col11" class="data row2 col11" >conventional</td>
#       <td id="T_52194_row2_col12" class="data row2 col12" >2015</td>
#       <td id="T_52194_row2_col13" class="data row2 col13" >Albany</td>
#     </tr>
#     <tr>
#       <td id="T_52194_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_52194_row

# %%
#데이터셋 정보 보기
print('\033[92m\033[1m'+'.: Imported Dataset Info :.'+'\033[0m')
print('\033[92m*' * 30+'\033[0m')
print('Total Rows:'+'\033[92m\033[1m', ds.shape[0])
print('\033[0m'+'Total Columns:'+'\033[92m\033[1m', ds.shape[1])
print('\033[0m\033[92m'+'*' * 30+'\033[0m')
print('\n')
# Out:
# .: Imported Dataset Info :.
# ******************************
# Total Rows: 18249
# Total Columns: 14
# ******************************

# %%
#데이터셋 디테일
print('\033[92m\033[1m'+'.: Dataset Details :.'+'\033[0m')
print('\033[0m\033[92m'+'*' * 30+'\033[0m')
ds.info(memory_usage = False)
# Out:
# .: Dataset Details :.
# ******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)

# %%
#범주형 변수 알아보기
#Avocado type 에 대해 시각화
# --- 색과 라벨 설정 ---
colors = color_mix[1:3]
labels = ds['type'].dropna().unique()
order = ds['type'].value_counts().index

# --- figure 사이즈 ---
plt.figure(figsize=(18, 10))

# --- 파이차트 ---
plt.subplot(1, 2, 1)
plt.title('Avocado Type Percentage', fontweight = 'bold', fontsize = 14, fontfamily = 'sans-serif', 
          color = black_grad[0])
plt.pie(ds['type'].value_counts(), labels = order, colors = colors, 
        wedgeprops = dict(alpha = 0.8, edgecolor = black_grad[1]), autopct = '%.2f%%')

# --- 바 차트 ---
countplt = plt.subplot(1, 2, 2)
plt.title('Avocado Type Bar Chart', fontweight = 'bold', fontsize = 14, fontfamily = 'sans-serif', color = black_grad[0])
ax = sns.countplot(x = 'type', data = ds, palette = colors, order = order, edgecolor = black_grad[2], alpha = 0.85)
for rect in ax.patches:
    ax.text (rect.get_x()+rect.get_width()/2, rect.get_height()+0.75,rect.get_height(), horizontalalignment = 'center', 
             fontsize = 11)

plt.xlabel('Types', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.ylabel('Total', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.grid(axis = 'y', alpha = 0.4)
countplt

# --- 범주형 변수 count ---
print('\033[92m'+'*' * 40)
print('\033[92m\033[1m'+'.: Total Avocado based on each Type :.'+'\033[0m')
print('\033[92m'+'*' * 40+'\033[0m')
ds.type.value_counts(dropna=False)

#eda 결과, conventional과 organic은 균일한 분포로 존재한다는 것을 확인할 수 있다.
# Out:
# ****************************************
# .: Total Avocado based on each Type :.
# ****************************************
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
#Year에 대해 시각화
# --- 색과 라벨 설정 ---
colors = sns.color_palette('YlOrBr')
labels = ds['year'].dropna().unique()
order = ds['year'].value_counts().index

# --- figure 사이즈 설정 ---
plt.figure(figsize=(18,10))

# --- Pie Chart ---
plt.subplot(1,2,1)
plt.title('Avocado Years Percentage', fontweight = 'bold', fontsize = 14, fontfamily = 'sans-serif', color = black_grad[0])
plt.pie(ds['year'].value_counts(), labels = order, colors = colors, 
        wedgeprops = dict(alpha = 0.8, edgecolor = black_grad[1]), autopct = '%.2f%%')

# --- Bar Chart ---
countplt = plt.subplot(1,2,2)
plt.title('Avocado Years Bar Chart', fontweight = 'bold', fontsize = 14, fontfamily = 'sans-serif', color = black_grad[0])
ax = sns.countplot(x = 'year', data = ds, palette = colors, order = order, edgecolor = black_grad[2], alpha = 0.85)
for rect in ax.patches:
    ax.text (rect.get_x()+rect.get_width()/2, rect.get_height()+0.75,rect.get_height(), horizontalalignment = 'center',
             fontsize = 10)

plt.xlabel('Years', fontweight = 'bold', fontsize = '11', fontfamily = 'sans-serif', color = black_grad[1])
plt.ylabel('Total', fontweight = 'bold', fontsize = '11', fontfamily = 'sans-serif', color = black_grad[1])
plt.grid(axis = 'y', alpha = 0.4)
countplt

# --- 범주형 변수 count ---
print('\033[92m'+'*' * 35)
print('\033[92m\033[1m'+'.: Total Avocado based on Year :.'+'\033[0m')
print('\033[92m'+'*' * 35+'\033[0m')
ds.year.value_counts(dropna=False)

#eda 결과, 2015-2017까지는 비슷한 분포로 아보카도가 수확되었지만, 2018에 눈에 띄게 낮은 것을 볼 수 있다.
# Out:
# ***********************************
# .: Total Avocado based on Year :.
# ***********************************
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: year, dtype: int64

# %%
#Region에 대해 시각화
# --- 범주형 변수 COUNT  ---
print('\033[92m'+'*' * 38)
print('\033[92m\033[1m'+'.: Total Avocado based on Regions :.'+'\033[0m')
print('\033[92m'+'*' * 38)
ds.region.value_counts(dropna=False)
# Out:
# **************************************
# .: Total Avocado based on Regions :.
# **************************************
# Albany                 338
# Sacramento             338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# Pittsburgh             338
# Plains                 338
# Portland               338
# RaleighGreensboro      338
# RichmondNorfolk        338
# Roanoke                338
# SanDiego               338
# Atlanta                338
# SanFrancisco           338
# Seattle                338
# SouthCarolina          338
# SouthCentral           338
# Southeast              338
# Spokane                338
# StLouis                338
# Syracuse               338
# Tampa                  338
# TotalUS                338
# West                   338
# NewYork                338
# NewOrleansMobile       338
# Nashville              338
# Midsouth               338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# California             338
# Charlotte              338
# Chicago                338
# CincinnatiDayton       338
# Columbus               338
# DallasFtWorth          338
# Denver                 338
# Detroit                338
# GrandRapids            338
# GreatLakes             338
# HarrisburgScranton     338
# HartfordSpringfield    338
# Houston                338
# Indianapolis           338
# Jacksonville           338
# LasVegas               338
# LosAngeles             338
# Louisville             338
# MiamiFtLauderdale      338
# WestTexNewMexico       335
# Name: region, dtype: int64

# %%
# --- 색과 라벨 설정 ---
colors = olive_grad[0:5]
labels = ds['region'].dropna().unique()
order = ds['region'].value_counts().index

# --- Pie Chart ---
plt.figure(figsize = (15, 15))
plt.title('Regions Percentage', fontweight = 'bold', fontsize = 14, fontfamily = 'sans-serif', color = black_grad[0])
plt.pie(ds['region'].value_counts(), labels = order, colors = colors, 
        wedgeprops = dict(alpha = 0.8, edgecolor = black_grad[1]), autopct = '%.2f%%');

# --- Bar Chart ---
plt.figure(figsize = (15, 15))
plt.title('Regions Bar Chart', fontweight = 'bold', fontsize = 14, fontfamily = 'sans-serif', color = black_grad[0])
sns.countplot(y = 'region', data = ds, order = order, palette = colors, edgecolor = black_grad[2], alpha = 0.85)
plt.xlabel('Total', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.ylabel('Regions', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.grid(axis = 'x', alpha = 0.4);

#Region은 전반적으로 고른 비율로 분포해있다.

# %%
#연속형 변수 알아보기
# --- 연속형 변수들 통계량 ---
ds[['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags', 'Large Bags', 
    'XLarge Bags']].describe().T.style.background_gradient(cmap='YlOrBr').set_properties(**{'font-family': 'Segoe UI'})
# Out:
# <style type="text/css">
# #T_b2e7b_row0_col0, #T_b2e7b_row0_col1, #T_b2e7b_row0_col2, #T_b2e7b_row0_col4, #T_b2e7b_row0_col5, #T_b2e7b_row0_col6, #T_b2e7b_row0_col7, #T_b2e7b_row1_col0, #T_b2e7b_row2_col0, #T_b2e7b_row2_col3, #T_b2e7b_row3_col0, #T_b2e7b_row3_col3, #T_b2e7b_row4_col0, #T_b2e7b_row4_col3, #T_b2e7b_row4_col4, #T_b2e7b_row4_col5, #T_b2e7b_row5_col0, #T_b2e7b_row5_col3, #T_b2e7b_row6_col0, #T_b2e7b_row6_col3, #T_b2e7b_row7_col0, #T_b2e7b_row7_col3, #T_b2e7b_row8_col0, #T_b2e7b_row8_col1, #T_b2e7b_row8_col3, #T_b2e7b_row8_col4, #T_b2e7b_row8_col5, #T_b2e7b_row8_col6 {
#   background-color: #ffffe5;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row0_col3, #T_b2e7b_row8_col2 {
#   background-color: #ffffe4;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row1_col1, #T_b2e7b_row1_col2, #T_b2e7b_row1_col3, #T_b2e7b_row1_col4, #T_b2e7b_row1_col5, #T_b2e7b_row1_col6, #T_b2e7b_row1_col7 {
#   background-color: #662506;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row2_col1, #T_b2e7b_row3_col1, #T_b2e7b_row3_col6 {
#   background-color: #fecb5f;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row2_col2, #T_b2e7b_row2_col7 {
#   background-color: #fec754;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row2_col4, #T_b2e7b_row2_col5 {
#   background-color: #fffacb;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row2_col6, #T_b2e7b_row5_col6 {
#   background-color: #fee28e;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row3_col2 {
#   background-color: #feca5d;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row3_col4 {
#   background-color: #fedc82;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row3_col5 {
#   background-color: #fede86;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row3_col7 {
#   background-color: #fed069;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row4_col1, #T_b2e7b_row7_col5 {
#   background-color: #fffddd;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row4_col2 {
#   background-color: #fffddc;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row4_col6, #T_b2e7b_row7_col4 {
#   background-color: #fffee1;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row4_col7 {
#   background-color: #fffcd8;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row5_col1 {
#   background-color: #fedb80;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row5_col2 {
#   background-color: #feda7e;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row5_col4 {
#   background-color: #fea332;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row5_col5 {
#   background-color: #fec652;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row5_col7 {
#   background-color: #fed471;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row6_col1, #T_b2e7b_row6_col7 {
#   background-color: #fee99e;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row6_col2 {
#   background-color: #fee89d;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row6_col4 {
#   background-color: #fee08a;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row6_col5 {
#   background-color: #fee493;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row6_col6 {
#   background-color: #feeca5;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row7_col1 {
#   background-color: #fffbd0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row7_col2 {
#   background-color: #ffface;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row7_col6 {
#   background-color: #fffcd4;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row7_col7 {
#   background-color: #fff9c7;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b2e7b_row8_col7 {
#   background-color: #fffee2;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_b2e7b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b2e7b_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_b2e7b_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_b2e7b_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_b2e7b_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_b2e7b_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_b2e7b_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_b2e7b_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_b2e7b_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2e7b_level0_row0" class="row_heading level0 row0" >AveragePrice</th>
#       <td id="T_b2e7b_row0_col0" class="data row0 col0" >18249.000000</td>
#       <td id="T_b2e7b_row0_col1" class="data row0 col1" >1.405978</td>
#       <td id="T_b2e7b_row0_col2" class="data row0 col2" >0.402677</td>
#       <td id="T_b2e7b_row0_col3" class="data row0 col3" >0.440000</td>
#       <td id="T_b2e7b_row0_col4" class="data row0 col4" >1.100000</td>
#       <td id="T_b2e7b_row0_col5" class="data row0 col5" >1.370000</td>
#       <td id="T_b2e7b_row0_col6" class="data row0 col6" >1.660000</td>
#       <td id="T_b2e7b_row0_col7" class="data row0 col7" >3.250000</td>
#     </tr>
#     <tr>
#       <th id="T_b2e7b_level0_row1" class="row_heading level0 row1" >Total Volume</th>
#       <td id="T_b2e7b_row1_col0" class="data row1 col0" >18249.000000</td>
#       <td id="T_b2e7b_row1_col1" class="data row1 col1" >850644.013009</td>
#       <td id="T_b2e7b_row1_col2" class="data row1 col2" >3453545.355399</td>
#       <td id="T_b2e7b_row1_col3" class="data row1 col3" >84.560000</td>
#       <td id="T_b2e7b_row1_col4" class="data row1 col4" >10838.580000</td>
#       <td id="T_b2e7b_row1_col5" class="data row1 col5" >107376.760000</td>
#       <td id="T_b2e7b_row1_col6" class="data row1 col6" >432962.290000</td>
#       <td id="T_b2e7b_row1_col7" class="data row1 col7" >62505646.520000</td>
#     </tr>
#     <tr>
#       <th id="T_b2e7b_level0_row2" class="row_heading level0 row2" >4046</th>
#       <td id="T_b2e7b_row2_col0" class="data row2 col0" >18249.000000</td>
#       <td id="T_b2e7b_row2_col1" class="data row2 col1" >293008.424531</td>
#       <td id="T_b2e7b_row2_col2" class="data row2 col2" >1264989.081763</td>
#       <td id="T_b2e7b_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_b2e7b_row2_col4" class="data row2 col4" >854.070000</td>
#       <td id="T_b2e7b_row2_col5" class="data row2 col5" >8645.300000</td>
#       <td id="T_b2e7b_row2_col6" class="data row2 col6" >111020.200000</td>
#       <td id="T_b2e7b_row2_col7" class="data row2 col7" >22743616.170000</td>
#     </tr>
#     <tr>
#       <th id="T_b2e7b_level0_row3" class="row_heading level0 row3" >4225</th>
#       <td id="T_b2e7b_row3_col0" class="data row3 col0" >18249.000000</td>
#       <td id="T_b2e7b_row3_col1" class="data row3 col1" >295154.568356</td>
#       <td id="T_b2e7b_row3_col2" class="data row3 col2" >1204120.401135</td>
#       <td id="T_b2e7b_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_b2e7b_row3_col4" class="data row3 col4" >3008.780000</td>
#       <td id="T_b2e7b_row3_col5" class="data row3 col5" >29061.020000</td>
#       <td id="T_b2e7b_row3_col6" class="data row3 col6" >150206.860000</td>
#       <td id="T_b2e7b_row3_col7" class="data row3 col7" >20470572.610000</td>
#     </tr>
#     <tr>
#       <th id="T_b2e7b_level0_row4" class="row_heading level0 row4" >4770</th>
#       <td id="T_b2e7b_row4_col0" class="data row4 col0" >18249.000000</td>
#       <td id="T_b2e7b_row4_col1" class="data row4 col1" >22839.735993</td>
#       <td id="T_b2e7b_row4_col2" class="data row4 col2" >107464.068435</td>
#       <td id="T_b2e7b_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_b2e7b_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_b2e7b_row4_col5" class="data row4 col5" >184.990000</td>
#       <td id="T_b2e7b_row4_col6" class="data row4 col6" >6243.420000</td>
#       <td id="T_b2e7b_row4_col7" class="data row4 col7" >2546439.110000</td>
#     </tr>
#     <tr>
#       <th id="T_b2e7b_level0_row5" class="row_heading level0 r

# %%
#연속형 변수들 시각화
# --- Plot Size ---
fig, axs = plt.subplots(9, 2, figsize = (16, 30))

# --- Title ---
fig.tight_layout()
fig.subplots_adjust(top = 0.95)
fig.suptitle('Histogram of Continuous Columns', fontweight = 'bold', fontsize = 16, fontfamily = 'sans-serif', 
             color = black_grad[0])

# --- Continuous Variables (Row 1) ---
sns.histplot(data = ds, x = 'AveragePrice', kde = True, ax = axs[0, 0], color = '#004D25')
sns.boxenplot(data = ds, x = 'AveragePrice', ax = axs[0, 1], color = '#004D25')

# --- Continuous Variables (Row 2) ---
sns.histplot(data = ds, x = 'Total Volume', kde = True, ax = axs[1, 0], color = '#EDDE30')
sns.boxenplot(data = ds, x = 'Total Volume', ax = axs[1, 1], color = '#EDDE30')

# --- Continuous Variables (Row 3) ---
sns.histplot(data = ds, x='4046', kde = True, ax = axs[2, 0], color = '#48BF53')
sns.boxenplot(data = ds, x = '4046', ax = axs[2, 1], color = '#48BF53')

# --- Continuous Variables (Row 4) ---
sns.histplot(data = ds, x = '4225', kde = True, ax = axs[3, 0], color = '#837A0B')
sns.boxenplot(data = ds, x = '4225', ax = axs[3, 1], color = '#837A0B')

# --- Continuous Variables (Row 5) ---
sns.histplot(data = ds, x = '4770', kde = True, ax = axs[4, 0], color = '#664228')
sns.boxenplot(data = ds, x = '4770', ax = axs[4, 1], color = '#664228')

# --- Continuous Variables (Row 6) ---
sns.histplot(data = ds, x = 'Total Bags', kde = True, ax = axs[5, 0], color = '#A4E637')
sns.boxenplot(data = ds, x = 'Total Bags', ax = axs[5, 1], color = '#A4E637')

# --- Continuous Variables (Row 7) ---
sns.histplot(data = ds, x = 'Small Bags', kde = True, ax = axs[6, 0], color = '#BF865D')
sns.boxenplot(data = ds, x = 'Small Bags', ax = axs[6, 1], color = '#BF865D')

# --- Continuous Variables (Row 8) ---
sns.histplot(data = ds, x = 'Large Bags', kde = True, ax = axs[7, 0], color = '#D98000')
sns.boxenplot(data = ds, x = 'Large Bags', ax = axs[7, 1], color = '#D98000')

# --- Continuous Variables (Row 9) ---
sns.histplot(data = ds, x = 'XLarge Bags', kde = True, ax = axs[8, 0], color = '#557F0F')
sns.boxenplot(data = ds, x = 'XLarge Bags', ax = axs[8, 1], color = '#557F0F');

#전반적으로 right-skewed 되어있음

# %%
# --- 연속형 변수의 왜곡도 ---
print('\033[92m\033[1m'+'.: Continuous Columns Skewness :.'+'\033[0m')
print('\033[92m*' * 34+'\033[0m')
ds[['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags', 'Large Bags', 
    'XLarge Bags']].skew(axis = 0, skipna = True)
# Out:
# .: Continuous Columns Skewness :.
# **********************************
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# dtype: float64

# %%
# --- 연속형 변수의 첨도 ---
print('\033[92m\033[1m'+'.: Continuous Columns Kurtosis :.'+'\033[0m')
print('\033[92m*' * 34+'\033[0m')
ds[['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags', 'Large Bags', 
    'XLarge Bags']].kurt(axis = 0, skipna = True)

# %%
#아보카도가 가장 많이 팔린 top5 region 알아보기
# --- type 에 따른 새로운 df 만들기 ---
eda0 = ds.xs(['region', 'Total Volume'], axis = 1)[ds.type == 'conventional']
eda0 = eda0[eda0['region'] != 'TotalUS']
eda0 = eda0.groupby(['region']).aggregate({'Total Volume': np.mean}).sort_values(by = 'Total Volume',
                                                                                 ascending = False).iloc[:5]

eda1 = ds.xs(['region', 'Total Volume'], axis = 1)[ds.type == 'organic']
eda1 = eda1[eda1['region'] != 'TotalUS']
eda1 = eda1.groupby(['region']).aggregate({'Total Volume': np.mean}).sort_values(by = 'Total Volume', 
                                                                                 ascending = False).iloc[:5]

# --- 바 차트 세팅 ---
fig, ax = plt.subplots(1, 2, figsize = (20, 6))
fig.suptitle('Top 5 Regions w/ The Most Sales', fontweight = 'heavy', fontsize = 16, fontfamily = 'sans-serif',
             color = black_grad[0])

# --- conventional avocado 바 차트 ---
plt.subplot(1, 2, 1)
plt.title('Conventional Avocado', fontweight = 'bold', fontsize = 12, fontfamily = 'sans-serif', color = black_grad[1])
bar_left = sns.barplot(x='Total Volume', y = eda0.index, data = eda0, palette = black_grad, edgecolor = black_grad[2], 
                       alpha = 0.85)
bar_left.patches[0].set_facecolor(olive_grad[0])
bar_left.patches[1].set_facecolor(olive_grad[1])
bar_left.patches[2].set_facecolor(olive_grad[2])
plt.xlabel('Total Volume', fontweight='bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.ylabel('Region', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.grid(axis = 'y', alpha = 0)
plt.grid(axis = 'x', alpha = 0.4)
plt.ticklabel_format(style = 'plain', axis = 'x')

# --- organic avocado 바 차트 ---
plt.subplot(1, 2, 2)
plt.title('Organic Avocado', fontweight = 'bold', fontsize = 12, fontfamily = 'sans-serif', color = black_grad[1])
bar_right = sns.barplot(x='Total Volume', y = eda1.index, data = eda1, palette = black_grad, edgecolor = black_grad[2],
                        alpha = 0.85)
bar_right.patches[0].set_facecolor(yellow_grad[1])
bar_right.patches[1].set_facecolor(yellow_grad[2])
bar_right.patches[2].set_facecolor(yellow_grad[3])
plt.xlabel('Total Volume', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.ylabel('Region', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.grid(axis = 'y', alpha = 0)
plt.grid(axis = 'x', alpha = 0.4)
plt.ticklabel_format(style = 'plain', axis = 'x')
plt.show();

#conventional avocado가 더 많이 팔린다
#West의 소비량이 가장 높음

# %%
#아보카도 가격이 높은 top 5 region
# --- type에 따른 새로운 df 형성 ---
eda2 = ds.xs(['region', 'AveragePrice'], axis = 1)[ds.type == 'conventional']
eda2 = eda2.groupby(['region']).aggregate({'AveragePrice': np.mean}).sort_values(by = 'AveragePrice', 
                                                                                 ascending = False).iloc[:5]

eda3 = ds.xs(['region', 'AveragePrice'], axis = 1)[ds.type == 'organic']
eda3 = eda3.groupby(['region']).aggregate({'AveragePrice': np.mean}).sort_values(by = 'AveragePrice',
                                                                                 ascending = False).iloc[:5]

# --- 바 차트 세팅 ---
fig, ax = plt.subplots(1, 2, figsize = (20, 6))
fig.suptitle('Top 5 Regions w/ Highest Avocado Price', fontweight = 'heavy', fontsize = 16, fontfamily = 'sans-serif', 
             color = black_grad[0])

# --- conventional avocado 바 차트 ---
plt.subplot(1, 2, 1)
plt.title('Conventional Avocado', fontweight = 'bold', fontsize = 12, fontfamily = 'sans-serif', color = black_grad[1])
bar_left = sns.barplot(y = 'AveragePrice', x = eda2.index, data = eda2, palette = black_grad, edgecolor = black_grad[2],
                       alpha = 0.85)
bar_left.patches[0].set_facecolor(olive_grad[0])
bar_left.patches[1].set_facecolor(olive_grad[1])
bar_left.patches[2].set_facecolor(olive_grad[2])
plt.xlabel('Price', fontweight = 'bold', fontsize = '11', fontfamily = 'sans-serif', color = black_grad[1])
plt.ylabel('Region', fontweight = 'bold', fontsize = '11', fontfamily = 'sans-serif', color = black_grad[1])
plt.grid(axis = 'y', alpha = 0.4)
plt.grid(axis = 'x', alpha = 0)
plt.ticklabel_format(style = 'plain', axis = 'y')

# --- organic avocado 바 차트 ---
plt.subplot(1, 2, 2)
plt.title('Organic Avocado', fontweight = 'bold', fontsize = '12', fontfamily = 'sans-serif', color = black_grad[1])
bar_right = sns.barplot(y='AveragePrice', x = eda3.index, data = eda3, palette = black_grad, edgecolor = black_grad[2],
                        alpha = 0.85)
bar_right.patches[0].set_facecolor(yellow_grad[1])
bar_right.patches[1].set_facecolor(yellow_grad[2])
bar_right.patches[2].set_facecolor(yellow_grad[3])
plt.xlabel('Price', fontweight='bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.ylabel('Region', fontweight = 'bold', fontsize = '11', fontfamily = 'sans-serif', color = black_grad[1])
plt.grid(axis = 'y', alpha = 0.4)
plt.grid(axis = 'x', alpha = 0)
plt.ticklabel_format(style = 'plain', axis = 'y')
plt.show();

#organic 이 더 비싸다
#둘 다 hartfordspringfield 가 가장 비쌈

# %%
#PLU에 따른 아보카도 판매량
# --- 새로운 DF 형성 ---
eda30 = ds.xs(['type', '4046', '4225', '4770'], axis = 1)
eda30 = eda30.groupby(['type']).aggregate({'4046': np.mean, '4225': np.mean, '4770': np.mean})

# --- 바 차트 ---
eda30.plot(kind='bar', stacked = True, color = color_mix[-4:-1], alpha = 0.85)
plt.title('Comparison of Avocado PLU Sold', fontweight = 'bold', fontsize = '12', fontfamily = 'sans-serif', 
          color = black_grad[1])
plt.xlabel('Type', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.ylabel('Avg. Total', fontweight = 'bold', fontsize = '11', fontfamily = 'sans-serif', color = black_grad[1])
plt.grid(axis = 'y', alpha = 0.4)
plt.grid(axis = 'x', alpha = 0)
plt.legend(labels = ['PLU 4046','PLU 4225', 'PLU 4770'], title = '$\\bf{Type}$', fontsize = '8', title_fontsize = '9',
           loc = 'upper right', frameon = True)
plt.xticks(rotation = 0)
plt.ticklabel_format(style = 'plain', axis = 'y');

# %%
#bag size에 따른 아보카도 판매량
# --- 새로운 df 생성 ---
eda31 = ds.xs(['type', 'Small Bags', 'Large Bags', 'XLarge Bags'], axis = 1)
eda31 = eda31.groupby(['type']).aggregate({'Small Bags': np.mean, 'Large Bags': np.mean, 'XLarge Bags': np.mean})

# --- Bar Chart ---
eda31.plot(kind = 'bar', stacked = True, color = color_mix[3:0:-1], alpha = 0.85)
plt.title('Bag Size Comparison', fontweight = 'bold', fontsize = 12, fontfamily = 'sans-serif', color = black_grad[1])
plt.xlabel('Type', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.ylabel('Avg. Total', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.grid(axis = 'y', alpha = 0.4)
plt.grid(axis = 'x', alpha = 0)
plt.legend(labels = ['Small Bags','Large Bags', 'XLarge Bags'], title = '$\\bf{Type}$', fontsize = 8, title_fontsize = 9,
           loc = 'upper right', frameon = True)
plt.xticks(rotation = 0)
plt.ticklabel_format(style = 'plain', axis = 'y');

# %%
#2015-2018 평균 아보카도 가격
# --- Type에 따른 box plot ---
fig, ax = plt.subplots()
fig.set_size_inches(17, 7)
plt.title('Average Price Distribution based on Types from 2015-2018', fontweight='bold', fontsize = 14, 
          fontfamily = 'sans-serif', color = black_grad[0])
sns.boxplot(x = 'year', y = 'AveragePrice', hue = 'type', data = ds, ax = ax, palette = color_mix[1:3], 
            boxprops = dict(alpha = 0.9), linewidth = 1.5)
plt.xlabel('Year', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.ylabel('Average Price', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.xticks(fontsize = 8)
plt.yticks(fontsize = 8)
plt.legend(title = '$\\bf{Type}$', fontsize = 8, title_fontsize = 9, loc = 'upper right', frameon = True)
plt.grid(axis = 'y', alpha = 0.4)
plt.show()

#항상 organic avocado가 conventional 에 비해 높다. 
#2017년에 아보카도 가격은 정점을 찍었고 , 2018년에 하락했다.

# %%
#total volume과 total bag의 산점도
# --- Type에 따라 total volume과 total bag 나누기 ---
x0 = ds.xs('Total Volume', axis = 1)[ds.type == 'conventional']
x1 = ds.xs('Total Volume', axis = 1)[ds.type == 'organic']
y0 = ds.xs('Total Bags', axis = 1)[ds.type == 'conventional']
y1 = ds.xs('Total Bags', axis = 1)[ds.type == 'organic']

# --- Scatter Plot ---
plt.figure(figsize = (8, 7))
plt.title('Scatter Plot between Avg. Price and Total Volume', fontweight = 'bold', fontsize = 14, 
          fontfamily = 'sans-serif', color = black_grad[0])
plt.scatter(x = x0, y = y0, c = color_mix[1], alpha = 0.6, linewidths = 1)
plt.scatter(x = x1, y = y1, c = color_mix[2], alpha = 0.6, linewidths = 1)
plt.legend(['Conventional', 'Organic'], title = '$\\bf{Type}$', fontsize = 7, title_fontsize = 8, loc = 'upper left',
           frameon = True)
plt.xlabel('Total Volume', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.ylabel('Total Bags', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif', color = black_grad[1])
plt.ticklabel_format(style = 'plain', axis = 'both')
plt.grid(axis = 'both', alpha = 0.5, lw = 0.5)
plt.show()

# %%
#아보카도 판매량 시계열 자료
# --- Calculating Mean of `Total Volume` grouped by Type and Date ---
dseda8 = ds[['Date', 'Total Volume', 'type']]
dseda8['Date'] = pd.DatetimeIndex(dseda8['Date'])
dseda8['Date'] = dseda8['Date'].apply(lambda x: x.strftime('%Y-%m'))
group8 = dseda8.groupby(['Date', 'type'])
mnth_avg8 = group8.aggregate({'Total Volume': np.mean})

# --- Creating Time Series Plot of Avg. Price ---
plt.figure(figsize = (10, 6))
plt.title('Avg. Avocado Sold based on Type from 2015-2018', fontweight = 'bold', fontsize = 14,
          fontfamily = 'sans-serif', color = black_grad[0])
sns.lineplot(data = mnth_avg8, x = 'Date', y = 'Total Volume', hue = 'type', style = 'type', markers = ['o', 'o'],
             palette = color_mix[0:2], alpha = 0.85)
plt.xlabel('Date (Year-Month)', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif')
plt.ylabel('Avg. Sold', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif')
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation = '90', fontsize = 7)
plt.yticks(rotation = '45', fontsize = 7)
plt.grid(axis='y', alpha = 0.5, lw = 0.6)
plt.grid(axis='x', alpha = 0)
plt.legend(labels = ['Conventional', 'Organic'], title = '$\\bf{Type}$', fontsize = 7, title_fontsize = 8, frameon=True);

# %%
#평균 가격에 대한 시계열 자료
# --- Calculating Mean of `AveragePrice` grouped by Type and Date ---
dseda9 = ds[['Date', 'AveragePrice', 'type']]
dseda9['Date'] = pd.DatetimeIndex(dseda9['Date'])
dseda9['Date'] = dseda9['Date'].apply(lambda x: x.strftime('%Y-%m'))
group9 = dseda9.groupby(['Date', 'type'])
mnth_avg9 = group9.aggregate({'AveragePrice': np.mean})

# --- Creating Time Series Plot of Avg. Price ---
plt.figure(figsize = (10, 6))
plt.title('Avg. Price of Avocado Type from 2015-2018', fontweight = 'bold', fontsize = 14, fontfamily = 'sans-serif',
          color = black_grad[0])
sns.lineplot(data = mnth_avg9, x = 'Date', y = 'AveragePrice', hue = 'type', style = 'type', markers = ['o', 'o'],
             palette = 'YlOrBr_r', alpha = 0.85)
plt.xlabel('Date (Year-Month)', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif')
plt.ylabel('Average Price', fontweight = 'bold', fontsize = 11, fontfamily = 'sans-serif')
plt.ticklabel_format(style = 'plain', axis = 'y')
plt.xticks(rotation = '90', fontsize = 7)
plt.yticks(fontsize = 7)
plt.grid(axis = 'y', alpha = 0.5, lw = 0.6)
plt.grid(axis = 'x', alpha = 0)
plt.legend(labels = ['Conventional', 'Organic'], title = '$\\bf{Type}$', fontsize = 7, title_fontsize = 8,
           loc = 'upper left', frameon = True);

# %%
# --- Correlation Map (Heatmap) ---
plt.figure(figsize = (12, 8))
sns.heatmap(ds.corr(), annot = True, cmap = 'Greens_r', linewidths = 0.1)
plt.title('Correlation Map of Numerical Variables', fontsize = 14, fontweight = 'bold', fontfamily = 'sans-serif',
          color = black_grad[0]);

# %%
#데이터셋 전처리
# --- `Date` 를 datetime 형식으로 바꾸기---
ds.Date = pd.to_datetime(ds.Date)

# --- `Date` 에서 '월'을 추출 ---
ds['month'] = pd.DatetimeIndex(ds['Date']).month

# %%
# --- Setup PyCaret Regression Module ---
avc = setup(data = ds, target = 'AveragePrice', train_size = 0.8,
            categorical_features = ['type', 'year', 'region', 'month'], normalize = True, normalize_method = 'robust', 
            session_id = 123)

#아마 파이캐럿에서 silent와 ignore_low_variance 기능이 사라진듯 합니다...
# Out:
# <style type="text/css">
# #T_d8a14_row11_col1, #T_d8a14_row17_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d8a14">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8a14_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d8a14_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8a14_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d8a14_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d8a14_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_d8a14_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d8a14_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d8a14_row1_col1" class="data row1 col1" >AveragePrice</td>
#     </tr>
#     <tr>
#       <th id="T_d8a14_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d8a14_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d8a14_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_d8a14_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d8a14_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_d8a14_row3_col1" class="data row3 col1" >(18249, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_d8a14_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d8a14_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_d8a14_row4_col1" class="data row4 col1" >(18249, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_d8a14_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d8a14_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_d8a14_row5_col1" class="data row5 col1" >(14599, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_d8a14_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d8a14_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_d8a14_row6_col1" class="data row6 col1" >(3650, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_d8a14_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d8a14_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_d8a14_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d8a14_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d8a14_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_d8a14_row8_col1" class="data row8 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_d8a14_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d8a14_row9_col0" class="data row9 col0" >Date features</td>
#       <td id="T_d8a14_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d8a14_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d8a14_row10_col0" class="data row10 col0" >Categorical features</td>
#       <td id="T_d8a14_row10_col1" class="data row10 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_d8a14_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d8a14_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_d8a14_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d8a14_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d8a14_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_d8a14_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d8a14_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d8a14_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_d8a14_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d8a14_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d8a14_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_d8a14_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_d8a14_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d8a14_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_d8a14_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_d8a14_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d8a14_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_d8a14_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d8a14_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d8a14_row17_col0" class="data row17 col0" >Normalize</td>
#       <td id="T_d8a14_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d8a14_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d8a14_row18_col0" class="data row18 col0" >Normalize method</td>
#       <td id="T_d8a14_row18_col1" class="data row18 col1" >robust</td>
#     </tr>
#     <tr>
#       <th id="T_d8a14_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d8a14_row19_col0" class="data row19 col0" >Fold Generator</td>
#       <td id="T_d8a14_row19_col1" class="data row19 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_d8a14_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_d8a14_row20_col0" class="data row20 col0" >Fold Number</td>
#       <td id="T_d8a14_row20_col1" class="data row20 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d8a14_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_d8a14_row21_col0" class="data row21 col0" >CPU Jobs</td>
#       <td id="T_d8a14_row21_col1" class="data row21 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d8a14_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_d8a14_row22_col0" class="data row22 col0" >Use GPU</td>
#       <td id="T_d8a14_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d8a14_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_d8a14_row23_col0" class="data row23 col0" >Log Experiment</td>
#       <td id="T_d8a14_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d8a14_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_d8a14_row24_col0" class="data row24 col0" >Experiment Name</td>
#       <td id="T_d8a14_row24_col1" class="data row24 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d8a14_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_d8a14_row25_col0" class="data row25 col0" >USI</td>
#       <td id="T_d8a14_row25_col1" class="data row25 col1" >56a3</td>
#     </tr>
#   </tbody>
# </table>

# %%
# --- List PyCaret Regression Models ---
models()
# Out:
#                                        Name  \
# ID
# lr                        Linear Regression
# lasso                      Lasso Regression
# ridge                      Ridge Regression
# en                              Elastic Net
# lar                  Least Angle Regression
# llar           Lasso Least Angle Regression
# omp             Orthogonal Matching Pursuit
# br                           Bayesian Ridge
# ard       Automatic Relevance Determination
# par            Passive Aggressive Regressor
# ransac              Random Sample Consensus
# tr                       TheilSen Regressor
# huber                       Huber Regressor
# kr                             Kernel Ridge
# svm               Support Vector Regression
# knn                   K Neighbors Regressor
# dt                  Decision Tree Regressor
# rf                  Random Forest Regressor
# et                    Extra Trees Regressor
# ada                      AdaBoost Regressor
# gbr             Gradient Boosting Regressor
# mlp                           MLP Regressor
# xgboost           Extreme Gradient Boosting
# lightgbm    Light Gradient Boosting Machine
# catboost                 CatBoost Regressor
# dummy                       Dummy Regressor
#
#                                                   Reference  Turbo
# ID
# lr              sklearn.linear_model._base.LinearRegression   True
# lasso        sklearn.linear_model._coordinate_descent.Lasso   True
# ridge                     sklearn.linear_model._ridge.Ridge   True
# en        sklearn.linear_model._coordinate_descent.Elast...   True
# lar                  sklearn.linear_model._least_angle.Lars   True
# llar            sklearn.linear_model._least_angle.LassoLars   True
# omp       sklearn.linear_model._omp.OrthogonalMatchingPu...   True
# br                sklearn.linear_model._bayes.BayesianRidge   True
# ard               sklearn.linear_model._bayes.ARDRegression  False
# par       sklearn.linear_model._passive_aggressive.Passi...   True
# ransac         sklearn.linear_model._ransac.RANSACRegressor  False
# tr        sklearn.linear_model._theil_sen.TheilSenRegressor  False
# huber            sklearn.linear_model._huber.HuberRegressor   True
# kr                         sklearn.kernel_ridge.KernelRidge  False
# svm                                sklearn.svm._classes.SVR  False
# knn       sklearn.neighbors._regression.KNeighborsRegressor   True
# dt              sklearn.tree._classes.DecisionTreeRegressor   True
# rf           sklearn.ensemble._forest.RandomForestRegressor   True
# et             sklearn.ensemble._forest.ExtraTreesRegressor   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostRegr...   True
# gbr          sklearn.ensemble._gb.GradientBoostingRegressor   True
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# xgboost                        xgboost.sklearn.XGBRegressor   True
# lightgbm                     lightgbm.sklearn.LGBMRegressor   True
# catboost                    catboost.core.CatBoostRegressor   True
# dummy                          sklearn.dummy.DummyRegressor   True

# %%
# --- Comparing All Models ---
best_models = compare_models(sort='R2')
# Out:
# <style type="text/css">
# #T_55a7e th {
#   text-align: left;
# }
# #T_55a7e_row0_col0, #T_55a7e_row1_col0, #T_55a7e_row1_col1, #T_55a7e_row1_col2, #T_55a7e_row1_col3, #T_55a7e_row1_col4, #T_55a7e_row1_col5, #T_55a7e_row1_col6, #T_55a7e_row2_col0, #T_55a7e_row2_col1, #T_55a7e_row2_col2, #T_55a7e_row2_col3, #T_55a7e_row2_col4, #T_55a7e_row2_col5, #T_55a7e_row2_col6, #T_55a7e_row3_col0, #T_55a7e_row3_col1, #T_55a7e_row3_col2, #T_55a7e_row3_col3, #T_55a7e_row3_col4, #T_55a7e_row3_col5, #T_55a7e_row3_col6, #T_55a7e_row4_col0, #T_55a7e_row4_col1, #T_55a7e_row4_col2, #T_55a7e_row4_col3, #T_55a7e_row4_col4, #T_55a7e_row4_col5, #T_55a7e_row4_col6, #T_55a7e_row5_col0, #T_55a7e_row5_col1, #T_55a7e_row5_col2, #T_55a7e_row5_col3, #T_55a7e_row5_col4, #T_55a7e_row5_col5, #T_55a7e_row5_col6, #T_55a7e_row6_col0, #T_55a7e_row6_col1, #T_55a7e_row6_col2, #T_55a7e_row6_col3, #T_55a7e_row6_col4, #T_55a7e_row6_col5, #T_55a7e_row6_col6, #T_55a7e_row7_col0, #T_55a7e_row7_col1, #T_55a7e_row7_col2, #T_55a7e_row7_col3, #T_55a7e_row7_col4, #T_55a7e_row7_col5, #T_55a7e_row7_col6, #T_55a7e_row8_col0, #T_55a7e_row8_col1, #T_55a7e_row8_col2, #T_55a7e_row8_col3, #T_55a7e_row8_col4, #T_55a7e_row8_col5, #T_55a7e_row8_col6, #T_55a7e_row9_col0, #T_55a7e_row9_col1, #T_55a7e_row9_col2, #T_55a7e_row9_col3, #T_55a7e_row9_col4, #T_55a7e_row9_col5, #T_55a7e_row9_col6, #T_55a7e_row10_col0, #T_55a7e_row10_col1, #T_55a7e_row10_col2, #T_55a7e_row10_col3, #T_55a7e_row10_col4, #T_55a7e_row10_col5, #T_55a7e_row10_col6, #T_55a7e_row11_col0, #T_55a7e_row11_col1, #T_55a7e_row11_col2, #T_55a7e_row11_col3, #T_55a7e_row11_col4, #T_55a7e_row11_col5, #T_55a7e_row11_col6, #T_55a7e_row12_col0, #T_55a7e_row12_col1, #T_55a7e_row12_col2, #T_55a7e_row12_col3, #T_55a7e_row12_col4, #T_55a7e_row12_col5, #T_55a7e_row12_col6, #T_55a7e_row13_col0, #T_55a7e_row13_col1, #T_55a7e_row13_col2, #T_55a7e_row13_col3, #T_55a7e_row13_col4, #T_55a7e_row13_col5, #T_55a7e_row13_col6, #T_55a7e_row14_col0, #T_55a7e_row14_col1, #T_55a7e_row14_col2, #T_55a7e_row14_col3, #T_55a7e_row14_col4, #T_55a7e_row14_col5, #T_55a7e_row14_col6, #T_55a7e_row15_col0, #T_55a7e_row15_col1, #T_55a7e_row15_col2, #T_55a7e_row15_col3, #T_55a7e_row15_col4, #T_55a7e_row15_col5, #T_55a7e_row15_col6, #T_55a7e_row16_col0, #T_55a7e_row16_col1, #T_55a7e_row16_col2, #T_55a7e_row16_col3, #T_55a7e_row16_col4, #T_55a7e_row16_col5, #T_55a7e_row16_col6, #T_55a7e_row17_col0, #T_55a7e_row17_col1, #T_55a7e_row17_col2, #T_55a7e_row17_col3, #T_55a7e_row17_col4, #T_55a7e_row17_col5, #T_55a7e_row17_col6, #T_55a7e_row18_col0, #T_55a7e_row18_col1, #T_55a7e_row18_col2, #T_55a7e_row18_col3, #T_55a7e_row18_col4, #T_55a7e_row18_col5, #T_55a7e_row18_col6, #T_55a7e_row19_col0, #T_55a7e_row19_col1, #T_55a7e_row19_col2, #T_55a7e_row19_col3, #T_55a7e_row19_col4, #T_55a7e_row19_col5, #T_55a7e_row19_col6 {
#   text-align: left;
# }
# #T_55a7e_row0_col1, #T_55a7e_row0_col2, #T_55a7e_row0_col3, #T_55a7e_row0_col4, #T_55a7e_row0_col5, #T_55a7e_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_55a7e_row0_col7, #T_55a7e_row1_col7, #T_55a7e_row2_col7, #T_55a7e_row3_col7, #T_55a7e_row4_col7, #T_55a7e_row5_col7, #T_55a7e_row6_col7, #T_55a7e_row7_col7, #T_55a7e_row8_col7, #T_55a7e_row9_col7, #T_55a7e_row11_col7, #T_55a7e_row12_col7, #T_55a7e_row13_col7, #T_55a7e_row14_col7, #T_55a7e_row15_col7, #T_55a7e_row16_col7, #T_55a7e_row17_col7, #T_55a7e_row18_col7, #T_55a7e_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_55a7e_row10_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_55a7e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55a7e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_55a7e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_55a7e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_55a7e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_55a7e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_55a7e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_55a7e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_55a7e_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55a7e_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_55a7e_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_55a7e_row0_col1" class="data row0 col1" >0.0739</td>
#       <td id="T_55a7e_row0_col2" class="data row0 col2" >0.0117</td>
#       <td id="T_55a7e_row0_col3" class="data row0 col3" >0.1081</td>
#       <td id="T_55a7e_row0_col4" class="data row0 col4" >0.9278</td>
#       <td id="T_55a7e_row0_col5" class="data row0 col5" >0.0435</td>
#       <td id="T_55a7e_row0_col6" class="data row0 col6" >0.0545</td>
#       <td id="T_55a7e_row0_col7" class="data row0 col7" >3.3730</td>
#     </tr>
#     <tr>
#       <th id="T_55a7e_level0_row1" class="row_heading level0 row1" >catboost</th>
#       <td id="T_55a7e_row1_col0" class="data row1 col0" >CatBoost Regressor</td>
#       <td id="T_55a7e_row1_col1" class="data row1 col1" >0.0832</td>
#       <td id="T_55a7e_row1_col2" class="data row1 col2" >0.0130</td>
#       <td id="T_55a7e_row1_col3" class="data row1 col3" >0.1138</td>
#       <td id="T_55a7e_row1_col4" class="data row1 col4" >0.9199</td>
#       <td id="T_55a7e_row1_col5" class="data row1 col5" >0.0455</td>
#       <td id="T_55a7e_row1_col6" class="data row1 col6" >0.0608</td>
#       <td id="T_55a7e_row1_col7" class="data row1 col7" >5.0320</td>
#     </tr>
#     <tr>
#       <th id="T_55a7e_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_55a7e_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_55a7e_row2_col1" class="data row2 col1" >0.0801</td>
#       <td id="T_55a7e_row2_col2" class="data row2 col2" >0.0132</td>
#       <td id="T_55a7e_row2_col3" class="data row2 col3" >0.1146</td>
#       <td id="T_55a7e_row2_col4" class="data row2 col4" >0.9187</td>
#       <td id="T_55a7e_row2_col5" class="data row2 col5" >0.0460</td>
#       <td id="T_55a7e_row2_col6" class="data row2 col6" >0.0592</td>
#       <td id="T_55a7e_row2_col7" class="data row2 col7" >5.2010</td>
#     </tr>
#     <tr>
#       <th id="T_55a7e_level0_row3" class="row_heading level0 row3" >xgboost</th>
#       <td id="T_55a7e_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_55a7e_row3_col1" class="data row3 col1" >0.0860</td>
#       <td id="T_55a7e_row3_col2" class="data row3 col2" >0.0139</td>
#       <td id="T_55a7e_row3_col3" class="data row3 col3" >0.1179</td>
#       <td id="T_55a7e_row3_col4" class="data row3 col4" >0.9140</td>
#       <td id="T_55a7e_row3_col5" class="data row3 col5" >0.0472</td>
#       <td id="T_55a7e_row3_col6" class="data row3 col6" >0.0628</td>
#       <td id="T_55a7e_row3_col7" class="data row3 col7" >2.2560</td>
#     </tr>
#     <tr>
#       <th id="T_55a7e_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_55a7e_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_55a7e_row4_col1" class="data row4 col1" >0.0986</td>
#       <td id="T_55a7e_row4_col2" class="data row4 col2" >0.0174</td>
#       <td id="T_55a7e_row4_col3" class="data row4 col3" >0.1320</td>
#       <td id="T_55a7e_row4_col4" class="data row4 col4" >0.8922</td>
#       <td id="T_55a7e_row4_col5" class="data row4 col5" >0.0535</td>
#       <td id="T_55a7e_row4_col6" class="data row4 col6" >0.0731</td>
#       <td id="T_55a7e_row4_col7" class="data row4 col7" >0.6430</td>
#     </tr>
#     <tr>
#       <th id="T_55a7e_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_55a7e_row5_col0" class="data row5 col0" >Decision Tree Regressor</td>
#       <td id="T_55a7e_row5_col1" class="data row5 col1" >0.1115</td>
#       <td id="T_55a7e_row5_col2" class="data row5 col2" >0.0284</td>
#       <td id="T_55a7e_row5_col3" class="data row5 c
# Processing:   0%|          | 0/85 [00:00<?, ?it/s]

# %%
# --- Plot the Residual of Best Model (et) ---
plot_model(best_models)

# %%
# --- Plot Error Prediction for Best Model ---
plot_model(best_models, plot = 'error')

# %%
# --- Plot Feature Importance for Best Model ---
plot_model(best_models, plot = 'feature')

# %%
# --- Tuning Best Model ---
tuned_best = tune_model(best_models)
# Out:
# <style type="text/css">
# #T_49793_row10_col0, #T_49793_row10_col1, #T_49793_row10_col2, #T_49793_row10_col3, #T_49793_row10_col4, #T_49793_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_49793">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49793_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_49793_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_49793_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_49793_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_49793_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_49793_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49793_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_49793_row0_col0" class="data row0 col0" >0.1933</td>
#       <td id="T_49793_row0_col1" class="data row0 col1" >0.0671</td>
#       <td id="T_49793_row0_col2" class="data row0 col2" >0.2590</td>
#       <td id="T_49793_row0_col3" class="data row0 col3" >0.5994</td>
#       <td id="T_49793_row0_col4" class="data row0 col4" >0.1029</td>
#       <td id="T_49793_row0_col5" class="data row0 col5" >0.1462</td>
#     </tr>
#     <tr>
#       <th id="T_49793_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_49793_row1_col0" class="data row1 col0" >0.2001</td>
#       <td id="T_49793_row1_col1" class="data row1 col1" >0.0687</td>
#       <td id="T_49793_row1_col2" class="data row1 col2" >0.2621</td>
#       <td id="T_49793_row1_col3" class="data row1 col3" >0.6020</td>
#       <td id="T_49793_row1_col4" class="data row1 col4" >0.1049</td>
#       <td id="T_49793_row1_col5" class="data row1 col5" >0.1511</td>
#     </tr>
#     <tr>
#       <th id="T_49793_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_49793_row2_col0" class="data row2 col0" >0.1885</td>
#       <td id="T_49793_row2_col1" class="data row2 col1" >0.0597</td>
#       <td id="T_49793_row2_col2" class="data row2 col2" >0.2443</td>
#       <td id="T_49793_row2_col3" class="data row2 col3" >0.6041</td>
#       <td id="T_49793_row2_col4" class="data row2 col4" >0.1021</td>
#       <td id="T_49793_row2_col5" class="data row2 col5" >0.1504</td>
#     </tr>
#     <tr>
#       <th id="T_49793_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_49793_row3_col0" class="data row3 col0" >0.1917</td>
#       <td id="T_49793_row3_col1" class="data row3 col1" >0.0660</td>
#       <td id="T_49793_row3_col2" class="data row3 col2" >0.2568</td>
#       <td id="T_49793_row3_col3" class="data row3 col3" >0.5991</td>
#       <td id="T_49793_row3_col4" class="data row3 col4" >0.1034</td>
#       <td id="T_49793_row3_col5" class="data row3 col5" >0.1473</td>
#     </tr>
#     <tr>
#       <th id="T_49793_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_49793_row4_col0" class="data row4 col0" >0.1955</td>
#       <td id="T_49793_row4_col1" class="data row4 col1" >0.0653</td>
#       <td id="T_49793_row4_col2" class="data row4 col2" >0.2555</td>
#       <td id="T_49793_row4_col3" class="data row4 col3" >0.6013</td>
#       <td id="T_49793_row4_col4" class="data row4 col4" >0.1032</td>
#       <td id="T_49793_row4_col5" class="data row4 col5" >0.1499</td>
#     </tr>
#     <tr>
#       <th id="T_49793_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_49793_row5_col0" class="data row5 col0" >0.1875</td>
#       <td id="T_49793_row5_col1" class="data row5 col1" >0.0606</td>
#       <td id="T_49793_row5_col2" class="data row5 col2" >0.2463</td>
#       <td id="T_49793_row5_col3" class="data row5 col3" >0.5996</td>
#       <td id="T_49793_row5_col4" class="data row5 col4" >0.1015</td>
#       <td id="T_49793_row5_col5" class="data row5 col5" >0.1479</td>
#     </tr>
#     <tr>
#       <th id="T_49793_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_49793_row6_col0" class="data row6 col0" >0.1940</td>
#       <td id="T_49793_row6_col1" class="data row6 col1" >0.0650</td>
#       <td id="T_49793_row6_col2" class="data row6 col2" >0.2549</td>
#       <td id="T_49793_row6_col3" class="data row6 col3" >0.5947</td>
#       <td id="T_49793_row6_col4" class="data row6 col4" >0.1046</td>
#       <td id="T_49793_row6_col5" class="data row6 col5" >0.1525</td>
#     </tr>
#     <tr>
#       <th id="T_49793_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_49793_row7_col0" class="data row7 col0" >0.1977</td>
#       <td id="T_49793_row7_col1" class="data row7 col1" >0.0733</td>
#       <td id="T_49793_row7_col2" class="data row7 col2" >0.2708</td>
#       <td id="T_49793_row7_col3" class="data row7 col3" >0.5678</td>
#       <td id="T_49793_row7_col4" class="data row7 col4" >0.1069</td>
#       <td id="T_49793_row7_col5" class="data row7 col5" >0.1474</td>
#     </tr>
#     <tr>
#       <th id="T_49793_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_49793_row8_col0" class="data row8 col0" >0.1967</td>
#       <td id="T_49793_row8_col1" class="data row8 col1" >0.0677</td>
#       <td id="T_49793_row8_col2" class="data row8 col2" >0.2602</td>
#       <td id="T_49793_row8_col3" class="data row8 col3" >0.5709</td>
#       <td id="T_49793_row8_col4" class="data row8 col4" >0.1064</td>
#       <td id="T_49793_row8_col5" class="data row8 col5" >0.1534</td>
#     </tr>
#     <tr>
#       <th id="T_49793_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_49793_row9_col0" class="data row9 col0" >0.1923</td>
#       <td id="T_49793_row9_col1" class="data row9 col1" >0.0652</td>
#       <td id="T_49793_row9_col2" class="data row9 col2" >0.2553</td>
#       <td id="T_49793_row9_col3" class="data row9 col3" >0.5977</td>
#       <td id="T_49793_row9_col4" class="data row9 col4" >0.1041</td>
#       <td id="T_49793_row9_col5" class="data row9 col5" >0.1512</td>
#     </tr>
#     <tr>
#       <th id="T_49793_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_49793_row10_col0" class="data row10 col0" >0.1937</td>
#       <td id="T_49793_row10_col1" class="data row10 col1" >0.0659</td>
#       <td id="T_49793_row10_col2" class="data row10 col2" >0.2565</td>
#       <td id="T_49793_row10_col3" class="data row10 col3" >0.5937</td>
#       <td id="T_49793_row10_col4" class="data row10 col4" >0.1040</td>
#       <td id="T_49793_row10_col5" class="data row10 col5" >0.1497</td>
#     </tr>
#     <tr>
#       <th id="T_49793_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_49793_row11_col0" class="data row11 col0" >0.0037</td>
#       <td id="T_49793_row11_col1" class="data row11 col1" >0.0037</td>
#       <td id="T_49793_row11_col2" class="data row11 col2" >0.0072</td>
#       <td id="T_49793_row11_col3" class="data row11 col3" >0.0124</td>
#       <td id="T_49793_row11_col4" class="data row11 col4" >0.0017</td>
#       <td id="T_49793_row11_col5" class="data row11 col5" >0.0023</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
# --- Plot the Residual of Tuned Best Model ---
plot_model(tuned_best)

# %%
# --- Plot Error Prediction for Tuned Best Model ---
plot_model(tuned_best, plot = 'error')

# %%
# --- Plot Feature Importance for Tuned Best Model ---
plot_model(tuned_best, plot = 'feature')

# %%
#모델의 적합도를 살펴본 결과, 랜덤포레스트 모델과 LightGBM 채택
# --- 랜덤 포레스트 모델 생성 ---
rf = create_model('rf')
# Out:
# <style type="text/css">
# #T_28ebe_row10_col0, #T_28ebe_row10_col1, #T_28ebe_row10_col2, #T_28ebe_row10_col3, #T_28ebe_row10_col4, #T_28ebe_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_28ebe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28ebe_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_28ebe_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_28ebe_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_28ebe_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_28ebe_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_28ebe_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28ebe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_28ebe_row0_col0" class="data row0 col0" >0.0813</td>
#       <td id="T_28ebe_row0_col1" class="data row0 col1" >0.0140</td>
#       <td id="T_28ebe_row0_col2" class="data row0 col2" >0.1183</td>
#       <td id="T_28ebe_row0_col3" class="data row0 col3" >0.9164</td>
#       <td id="T_28ebe_row0_col4" class="data row0 col4" >0.0466</td>
#       <td id="T_28ebe_row0_col5" class="data row0 col5" >0.0591</td>
#     </tr>
#     <tr>
#       <th id="T_28ebe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_28ebe_row1_col0" class="data row1 col0" >0.0800</td>
#       <td id="T_28ebe_row1_col1" class="data row1 col1" >0.0120</td>
#       <td id="T_28ebe_row1_col2" class="data row1 col2" >0.1096</td>
#       <td id="T_28ebe_row1_col3" class="data row1 col3" >0.9304</td>
#       <td id="T_28ebe_row1_col4" class="data row1 col4" >0.0446</td>
#       <td id="T_28ebe_row1_col5" class="data row1 col5" >0.0587</td>
#     </tr>
#     <tr>
#       <th id="T_28ebe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_28ebe_row2_col0" class="data row2 col0" >0.0791</td>
#       <td id="T_28ebe_row2_col1" class="data row2 col1" >0.0127</td>
#       <td id="T_28ebe_row2_col2" class="data row2 col2" >0.1129</td>
#       <td id="T_28ebe_row2_col3" class="data row2 col3" >0.9155</td>
#       <td id="T_28ebe_row2_col4" class="data row2 col4" >0.0461</td>
#       <td id="T_28ebe_row2_col5" class="data row2 col5" >0.0594</td>
#     </tr>
#     <tr>
#       <th id="T_28ebe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_28ebe_row3_col0" class="data row3 col0" >0.0791</td>
#       <td id="T_28ebe_row3_col1" class="data row3 col1" >0.0135</td>
#       <td id="T_28ebe_row3_col2" class="data row3 col2" >0.1161</td>
#       <td id="T_28ebe_row3_col3" class="data row3 col3" >0.9180</td>
#       <td id="T_28ebe_row3_col4" class="data row3 col4" >0.0459</td>
#       <td id="T_28ebe_row3_col5" class="data row3 col5" >0.0578</td>
#     </tr>
#     <tr>
#       <th id="T_28ebe_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_28ebe_row4_col0" class="data row4 col0" >0.0766</td>
#       <td id="T_28ebe_row4_col1" class="data row4 col1" >0.0114</td>
#       <td id="T_28ebe_row4_col2" class="data row4 col2" >0.1066</td>
#       <td id="T_28ebe_row4_col3" class="data row4 col3" >0.9306</td>
#       <td id="T_28ebe_row4_col4" class="data row4 col4" >0.0426</td>
#       <td id="T_28ebe_row4_col5" class="data row4 col5" >0.0563</td>
#     </tr>
#     <tr>
#       <th id="T_28ebe_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_28ebe_row5_col0" class="data row5 col0" >0.0765</td>
#       <td id="T_28ebe_row5_col1" class="data row5 col1" >0.0123</td>
#       <td id="T_28ebe_row5_col2" class="data row5 col2" >0.1107</td>
#       <td id="T_28ebe_row5_col3" class="data row5 col3" >0.9191</td>
#       <td id="T_28ebe_row5_col4" class="data row5 col4" >0.0448</td>
#       <td id="T_28ebe_row5_col5" class="data row5 col5" >0.0571</td>
#     </tr>
#     <tr>
#       <th id="T_28ebe_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_28ebe_row6_col0" class="data row6 col0" >0.0802</td>
#       <td id="T_28ebe_row6_col1" class="data row6 col1" >0.0137</td>
#       <td id="T_28ebe_row6_col2" class="data row6 col2" >0.1173</td>
#       <td id="T_28ebe_row6_col3" class="data row6 col3" >0.9142</td>
#       <td id="T_28ebe_row6_col4" class="data row6 col4" >0.0467</td>
#       <td id="T_28ebe_row6_col5" class="data row6 col5" >0.0589</td>
#     </tr>
#     <tr>
#       <th id="T_28ebe_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_28ebe_row7_col0" class="data row7 col0" >0.0835</td>
#       <td id="T_28ebe_row7_col1" class="data row7 col1" >0.0147</td>
#       <td id="T_28ebe_row7_col2" class="data row7 col2" >0.1213</td>
#       <td id="T_28ebe_row7_col3" class="data row7 col3" >0.9133</td>
#       <td id="T_28ebe_row7_col4" class="data row7 col4" >0.0478</td>
#       <td id="T_28ebe_row7_col5" class="data row7 col5" >0.0608</td>
#     </tr>
#     <tr>
#       <th id="T_28ebe_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_28ebe_row8_col0" class="data row8 col0" >0.0835</td>
#       <td id="T_28ebe_row8_col1" class="data row8 col1" >0.0137</td>
#       <td id="T_28ebe_row8_col2" class="data row8 col2" >0.1171</td>
#       <td id="T_28ebe_row8_col3" class="data row8 col3" >0.9131</td>
#       <td id="T_28ebe_row8_col4" class="data row8 col4" >0.0477</td>
#       <td id="T_28ebe_row8_col5" class="data row8 col5" >0.0624</td>
#     </tr>
#     <tr>
#       <th id="T_28ebe_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_28ebe_row9_col0" class="data row9 col0" >0.0809</td>
#       <td id="T_28ebe_row9_col1" class="data row9 col1" >0.0136</td>
#       <td id="T_28ebe_row9_col2" class="data row9 col2" >0.1165</td>
#       <td id="T_28ebe_row9_col3" class="data row9 col3" >0.9162</td>
#       <td id="T_28ebe_row9_col4" class="data row9 col4" >0.0474</td>
#       <td id="T_28ebe_row9_col5" class="data row9 col5" >0.0611</td>
#     </tr>
#     <tr>
#       <th id="T_28ebe_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_28ebe_row10_col0" class="data row10 col0" >0.0801</td>
#       <td id="T_28ebe_row10_col1" class="data row10 col1" >0.0132</td>
#       <td id="T_28ebe_row10_col2" class="data row10 col2" >0.1146</td>
#       <td id="T_28ebe_row10_col3" class="data row10 col3" >0.9187</td>
#       <td id="T_28ebe_row10_col4" class="data row10 col4" >0.0460</td>
#       <td id="T_28ebe_row10_col5" class="data row10 col5" >0.0592</td>
#     </tr>
#     <tr>
#       <th id="T_28ebe_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_28ebe_row11_col0" class="data row11 col0" >0.0023</td>
#       <td id="T_28ebe_row11_col1" class="data row11 col1" >0.0010</td>
#       <td id="T_28ebe_row11_col2" class="data row11 col2" >0.0043</td>
#       <td id="T_28ebe_row11_col3" class="data row11 col3" >0.0062</td>
#       <td id="T_28ebe_row11_col4" class="data row11 col4" >0.0015</td>
#       <td id="T_28ebe_row11_col5" class="data row11 col5" >0.0018</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
# --- 랜덤 포레스트 모델의 잔차 PLOT ---
plot_model(rf)

# %%
# --- 랜덤 포레스트 모델의 오류 예측 PLOT ---
plot_model(rf, plot = 'error')

# %%
# --- 랜덤 포레스트 모델의 피처 중요도 PLOT --
plot_model(rf, plot = 'feature')

# %%
# --- 랜덤 포레스트 모델 튜닝 ---
tune_rf = tune_model(rf)
# Out:
# <style type="text/css">
# #T_1f858_row10_col0, #T_1f858_row10_col1, #T_1f858_row10_col2, #T_1f858_row10_col3, #T_1f858_row10_col4, #T_1f858_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_1f858">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f858_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_1f858_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_1f858_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_1f858_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_1f858_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_1f858_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f858_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1f858_row0_col0" class="data row0 col0" >0.1527</td>
#       <td id="T_1f858_row0_col1" class="data row0 col1" >0.0429</td>
#       <td id="T_1f858_row0_col2" class="data row0 col2" >0.2072</td>
#       <td id="T_1f858_row0_col3" class="data row0 col3" >0.7436</td>
#       <td id="T_1f858_row0_col4" class="data row0 col4" >0.0817</td>
#       <td id="T_1f858_row0_col5" class="data row0 col5" >0.1129</td>
#     </tr>
#     <tr>
#       <th id="T_1f858_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1f858_row1_col0" class="data row1 col0" >0.1584</td>
#       <td id="T_1f858_row1_col1" class="data row1 col1" >0.0428</td>
#       <td id="T_1f858_row1_col2" class="data row1 col2" >0.2070</td>
#       <td id="T_1f858_row1_col3" class="data row1 col3" >0.7519</td>
#       <td id="T_1f858_row1_col4" class="data row1 col4" >0.0826</td>
#       <td id="T_1f858_row1_col5" class="data row1 col5" >0.1175</td>
#     </tr>
#     <tr>
#       <th id="T_1f858_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1f858_row2_col0" class="data row2 col0" >0.1531</td>
#       <td id="T_1f858_row2_col1" class="data row2 col1" >0.0390</td>
#       <td id="T_1f858_row2_col2" class="data row2 col2" >0.1975</td>
#       <td id="T_1f858_row2_col3" class="data row2 col3" >0.7413</td>
#       <td id="T_1f858_row2_col4" class="data row2 col4" >0.0818</td>
#       <td id="T_1f858_row2_col5" class="data row2 col5" >0.1186</td>
#     </tr>
#     <tr>
#       <th id="T_1f858_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1f858_row3_col0" class="data row3 col0" >0.1472</td>
#       <td id="T_1f858_row3_col1" class="data row3 col1" >0.0395</td>
#       <td id="T_1f858_row3_col2" class="data row3 col2" >0.1987</td>
#       <td id="T_1f858_row3_col3" class="data row3 col3" >0.7600</td>
#       <td id="T_1f858_row3_col4" class="data row3 col4" >0.0792</td>
#       <td id="T_1f858_row3_col5" class="data row3 col5" >0.1102</td>
#     </tr>
#     <tr>
#       <th id="T_1f858_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1f858_row4_col0" class="data row4 col0" >0.1540</td>
#       <td id="T_1f858_row4_col1" class="data row4 col1" >0.0403</td>
#       <td id="T_1f858_row4_col2" class="data row4 col2" >0.2007</td>
#       <td id="T_1f858_row4_col3" class="data row4 col3" >0.7539</td>
#       <td id="T_1f858_row4_col4" class="data row4 col4" >0.0806</td>
#       <td id="T_1f858_row4_col5" class="data row4 col5" >0.1157</td>
#     </tr>
#     <tr>
#       <th id="T_1f858_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1f858_row5_col0" class="data row5 col0" >0.1529</td>
#       <td id="T_1f858_row5_col1" class="data row5 col1" >0.0402</td>
#       <td id="T_1f858_row5_col2" class="data row5 col2" >0.2005</td>
#       <td id="T_1f858_row5_col3" class="data row5 col3" >0.7347</td>
#       <td id="T_1f858_row5_col4" class="data row5 col4" >0.0816</td>
#       <td id="T_1f858_row5_col5" class="data row5 col5" >0.1166</td>
#     </tr>
#     <tr>
#       <th id="T_1f858_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1f858_row6_col0" class="data row6 col0" >0.1575</td>
#       <td id="T_1f858_row6_col1" class="data row6 col1" >0.0435</td>
#       <td id="T_1f858_row6_col2" class="data row6 col2" >0.2086</td>
#       <td id="T_1f858_row6_col3" class="data row6 col3" >0.7285</td>
#       <td id="T_1f858_row6_col4" class="data row6 col4" >0.0847</td>
#       <td id="T_1f858_row6_col5" class="data row6 col5" >0.1203</td>
#     </tr>
#     <tr>
#       <th id="T_1f858_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1f858_row7_col0" class="data row7 col0" >0.1590</td>
#       <td id="T_1f858_row7_col1" class="data row7 col1" >0.0478</td>
#       <td id="T_1f858_row7_col2" class="data row7 col2" >0.2186</td>
#       <td id="T_1f858_row7_col3" class="data row7 col3" >0.7185</td>
#       <td id="T_1f858_row7_col4" class="data row7 col4" >0.0855</td>
#       <td id="T_1f858_row7_col5" class="data row7 col5" >0.1158</td>
#     </tr>
#     <tr>
#       <th id="T_1f858_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1f858_row8_col0" class="data row8 col0" >0.1609</td>
#       <td id="T_1f858_row8_col1" class="data row8 col1" >0.0444</td>
#       <td id="T_1f858_row8_col2" class="data row8 col2" >0.2108</td>
#       <td id="T_1f858_row8_col3" class="data row8 col3" >0.7183</td>
#       <td id="T_1f858_row8_col4" class="data row8 col4" >0.0856</td>
#       <td id="T_1f858_row8_col5" class="data row8 col5" >0.1222</td>
#     </tr>
#     <tr>
#       <th id="T_1f858_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1f858_row9_col0" class="data row9 col0" >0.1583</td>
#       <td id="T_1f858_row9_col1" class="data row9 col1" >0.0441</td>
#       <td id="T_1f858_row9_col2" class="data row9 col2" >0.2100</td>
#       <td id="T_1f858_row9_col3" class="data row9 col3" >0.7277</td>
#       <td id="T_1f858_row9_col4" class="data row9 col4" >0.0855</td>
#       <td id="T_1f858_row9_col5" class="data row9 col5" >0.1223</td>
#     </tr>
#     <tr>
#       <th id="T_1f858_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_1f858_row10_col0" class="data row10 col0" >0.1554</td>
#       <td id="T_1f858_row10_col1" class="data row10 col1" >0.0425</td>
#       <td id="T_1f858_row10_col2" class="data row10 col2" >0.2060</td>
#       <td id="T_1f858_row10_col3" class="data row10 col3" >0.7378</td>
#       <td id="T_1f858_row10_col4" class="data row10 col4" >0.0829</td>
#       <td id="T_1f858_row10_col5" class="data row10 col5" >0.1172</td>
#     </tr>
#     <tr>
#       <th id="T_1f858_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_1f858_row11_col0" class="data row11 col0" >0.0039</td>
#       <td id="T_1f858_row11_col1" class="data row11 col1" >0.0026</td>
#       <td id="T_1f858_row11_col2" class="data row11 col2" >0.0062</td>
#       <td id="T_1f858_row11_col3" class="data row11 col3" >0.0140</td>
#       <td id="T_1f858_row11_col4" class="data row11 col4" >0.0022</td>
#       <td id="T_1f858_row11_col5" class="data row11 col5" >0.0037</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
# --- TUNED된 랜덤 포레스트 모델의 잔차 PLOT ---
plot_model(tune_rf)

# %%
# --- TUNED된 랜덤 포레스트 모델의 오류 예측 PLOT ---
plot_model(tune_rf, plot = 'error')

# %%
# --- TUNED된 랜덤 포레스트 모델의 피처 중요도 PLOT---
plot_model(tune_rf, plot = 'feature')

# %%
# ---Light GBM 생성---
lgbm = create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_7f50f_row10_col0, #T_7f50f_row10_col1, #T_7f50f_row10_col2, #T_7f50f_row10_col3, #T_7f50f_row10_col4, #T_7f50f_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_7f50f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f50f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_7f50f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_7f50f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_7f50f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_7f50f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_7f50f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f50f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7f50f_row0_col0" class="data row0 col0" >0.0988</td>
#       <td id="T_7f50f_row0_col1" class="data row0 col1" >0.0176</td>
#       <td id="T_7f50f_row0_col2" class="data row0 col2" >0.1327</td>
#       <td id="T_7f50f_row0_col3" class="data row0 col3" >0.8948</td>
#       <td id="T_7f50f_row0_col4" class="data row0 col4" >0.0528</td>
#       <td id="T_7f50f_row0_col5" class="data row0 col5" >0.0719</td>
#     </tr>
#     <tr>
#       <th id="T_7f50f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7f50f_row1_col0" class="data row1 col0" >0.1005</td>
#       <td id="T_7f50f_row1_col1" class="data row1 col1" >0.0172</td>
#       <td id="T_7f50f_row1_col2" class="data row1 col2" >0.1310</td>
#       <td id="T_7f50f_row1_col3" class="data row1 col3" >0.9005</td>
#       <td id="T_7f50f_row1_col4" class="data row1 col4" >0.0531</td>
#       <td id="T_7f50f_row1_col5" class="data row1 col5" >0.0740</td>
#     </tr>
#     <tr>
#       <th id="T_7f50f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7f50f_row2_col0" class="data row2 col0" >0.0990</td>
#       <td id="T_7f50f_row2_col1" class="data row2 col1" >0.0171</td>
#       <td id="T_7f50f_row2_col2" class="data row2 col2" >0.1309</td>
#       <td id="T_7f50f_row2_col3" class="data row2 col3" >0.8864</td>
#       <td id="T_7f50f_row2_col4" class="data row2 col4" >0.0542</td>
#       <td id="T_7f50f_row2_col5" class="data row2 col5" >0.0751</td>
#     </tr>
#     <tr>
#       <th id="T_7f50f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7f50f_row3_col0" class="data row3 col0" >0.0943</td>
#       <td id="T_7f50f_row3_col1" class="data row3 col1" >0.0166</td>
#       <td id="T_7f50f_row3_col2" class="data row3 col2" >0.1287</td>
#       <td id="T_7f50f_row3_col3" class="data row3 col3" >0.8993</td>
#       <td id="T_7f50f_row3_col4" class="data row3 col4" >0.0516</td>
#       <td id="T_7f50f_row3_col5" class="data row3 col5" >0.0693</td>
#     </tr>
#     <tr>
#       <th id="T_7f50f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7f50f_row4_col0" class="data row4 col0" >0.0936</td>
#       <td id="T_7f50f_row4_col1" class="data row4 col1" >0.0151</td>
#       <td id="T_7f50f_row4_col2" class="data row4 col2" >0.1229</td>
#       <td id="T_7f50f_row4_col3" class="data row4 col3" >0.9078</td>
#       <td id="T_7f50f_row4_col4" class="data row4 col4" >0.0495</td>
#       <td id="T_7f50f_row4_col5" class="data row4 col5" >0.0690</td>
#     </tr>
#     <tr>
#       <th id="T_7f50f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7f50f_row5_col0" class="data row5 col0" >0.0966</td>
#       <td id="T_7f50f_row5_col1" class="data row5 col1" >0.0166</td>
#       <td id="T_7f50f_row5_col2" class="data row5 col2" >0.1289</td>
#       <td id="T_7f50f_row5_col3" class="data row5 col3" >0.8903</td>
#       <td id="T_7f50f_row5_col4" class="data row5 col4" >0.0526</td>
#       <td id="T_7f50f_row5_col5" class="data row5 col5" >0.0720</td>
#     </tr>
#     <tr>
#       <th id="T_7f50f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7f50f_row6_col0" class="data row6 col0" >0.0989</td>
#       <td id="T_7f50f_row6_col1" class="data row6 col1" >0.0181</td>
#       <td id="T_7f50f_row6_col2" class="data row6 col2" >0.1345</td>
#       <td id="T_7f50f_row6_col3" class="data row6 col3" >0.8872</td>
#       <td id="T_7f50f_row6_col4" class="data row6 col4" >0.0541</td>
#       <td id="T_7f50f_row6_col5" class="data row6 col5" >0.0732</td>
#     </tr>
#     <tr>
#       <th id="T_7f50f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7f50f_row7_col0" class="data row7 col0" >0.1024</td>
#       <td id="T_7f50f_row7_col1" class="data row7 col1" >0.0196</td>
#       <td id="T_7f50f_row7_col2" class="data row7 col2" >0.1399</td>
#       <td id="T_7f50f_row7_col3" class="data row7 col3" >0.8846</td>
#       <td id="T_7f50f_row7_col4" class="data row7 col4" >0.0557</td>
#       <td id="T_7f50f_row7_col5" class="data row7 col5" >0.0746</td>
#     </tr>
#     <tr>
#       <th id="T_7f50f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7f50f_row8_col0" class="data row8 col0" >0.0994</td>
#       <td id="T_7f50f_row8_col1" class="data row8 col1" >0.0173</td>
#       <td id="T_7f50f_row8_col2" class="data row8 col2" >0.1315</td>
#       <td id="T_7f50f_row8_col3" class="data row8 col3" >0.8903</td>
#       <td id="T_7f50f_row8_col4" class="data row8 col4" >0.0541</td>
#       <td id="T_7f50f_row8_col5" class="data row8 col5" >0.0747</td>
#     </tr>
#     <tr>
#       <th id="T_7f50f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7f50f_row9_col0" class="data row9 col0" >0.1019</td>
#       <td id="T_7f50f_row9_col1" class="data row9 col1" >0.0193</td>
#       <td id="T_7f50f_row9_col2" class="data row9 col2" >0.1388</td>
#       <td id="T_7f50f_row9_col3" class="data row9 col3" >0.8810</td>
#       <td id="T_7f50f_row9_col4" class="data row9 col4" >0.0568</td>
#       <td id="T_7f50f_row9_col5" class="data row9 col5" >0.0775</td>
#     </tr>
#     <tr>
#       <th id="T_7f50f_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_7f50f_row10_col0" class="data row10 col0" >0.0986</td>
#       <td id="T_7f50f_row10_col1" class="data row10 col1" >0.0174</td>
#       <td id="T_7f50f_row10_col2" class="data row10 col2" >0.1320</td>
#       <td id="T_7f50f_row10_col3" class="data row10 col3" >0.8922</td>
#       <td id="T_7f50f_row10_col4" class="data row10 col4" >0.0535</td>
#       <td id="T_7f50f_row10_col5" class="data row10 col5" >0.0731</td>
#     </tr>
#     <tr>
#       <th id="T_7f50f_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_7f50f_row11_col0" class="data row11 col0" >0.0028</td>
#       <td id="T_7f50f_row11_col1" class="data row11 col1" >0.0012</td>
#       <td id="T_7f50f_row11_col2" class="data row11 col2" >0.0047</td>
#       <td id="T_7f50f_row11_col3" class="data row11 col3" >0.0079</td>
#       <td id="T_7f50f_row11_col4" class="data row11 col4" >0.0019</td>
#       <td id="T_7f50f_row11_col5" class="data row11 col5" >0.0025</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
# --- Light GBM의 잔차 PLOT---
plot_model(lgbm)

# %%
# --- Light GBM의 예측 오류 PLOT---
plot_model(lgbm, plot = 'error')

# %%
# --- Light GBM의 피처 중요도 PLOT---
plot_model(lgbm, plot = 'feature')

# %%
# --- Light GBM 튜닝 ---
tune_lgbm = tune_model(lgbm)
# Out:
# <style type="text/css">
# #T_4ee85_row10_col0, #T_4ee85_row10_col1, #T_4ee85_row10_col2, #T_4ee85_row10_col3, #T_4ee85_row10_col4, #T_4ee85_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_4ee85">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ee85_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_4ee85_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_4ee85_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_4ee85_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_4ee85_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_4ee85_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ee85_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4ee85_row0_col0" class="data row0 col0" >0.1149</td>
#       <td id="T_4ee85_row0_col1" class="data row0 col1" >0.0252</td>
#       <td id="T_4ee85_row0_col2" class="data row0 col2" >0.1588</td>
#       <td id="T_4ee85_row0_col3" class="data row0 col3" >0.8495</td>
#       <td id="T_4ee85_row0_col4" class="data row0 col4" >0.0627</td>
#       <td id="T_4ee85_row0_col5" class="data row0 col5" >0.0838</td>
#     </tr>
#     <tr>
#       <th id="T_4ee85_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4ee85_row1_col0" class="data row1 col0" >0.1186</td>
#       <td id="T_4ee85_row1_col1" class="data row1 col1" >0.0242</td>
#       <td id="T_4ee85_row1_col2" class="data row1 col2" >0.1555</td>
#       <td id="T_4ee85_row1_col3" class="data row1 col3" >0.8599</td>
#       <td id="T_4ee85_row1_col4" class="data row1 col4" >0.0627</td>
#       <td id="T_4ee85_row1_col5" class="data row1 col5" >0.0871</td>
#     </tr>
#     <tr>
#       <th id="T_4ee85_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4ee85_row2_col0" class="data row2 col0" >0.1170</td>
#       <td id="T_4ee85_row2_col1" class="data row2 col1" >0.0242</td>
#       <td id="T_4ee85_row2_col2" class="data row2 col2" >0.1555</td>
#       <td id="T_4ee85_row2_col3" class="data row2 col3" >0.8397</td>
#       <td id="T_4ee85_row2_col4" class="data row2 col4" >0.0643</td>
#       <td id="T_4ee85_row2_col5" class="data row2 col5" >0.0890</td>
#     </tr>
#     <tr>
#       <th id="T_4ee85_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4ee85_row3_col0" class="data row3 col0" >0.1107</td>
#       <td id="T_4ee85_row3_col1" class="data row3 col1" >0.0223</td>
#       <td id="T_4ee85_row3_col2" class="data row3 col2" >0.1494</td>
#       <td id="T_4ee85_row3_col3" class="data row3 col3" >0.8643</td>
#       <td id="T_4ee85_row3_col4" class="data row3 col4" >0.0599</td>
#       <td id="T_4ee85_row3_col5" class="data row3 col5" >0.0818</td>
#     </tr>
#     <tr>
#       <th id="T_4ee85_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4ee85_row4_col0" class="data row4 col0" >0.1117</td>
#       <td id="T_4ee85_row4_col1" class="data row4 col1" >0.0225</td>
#       <td id="T_4ee85_row4_col2" class="data row4 col2" >0.1500</td>
#       <td id="T_4ee85_row4_col3" class="data row4 col3" >0.8625</td>
#       <td id="T_4ee85_row4_col4" class="data row4 col4" >0.0601</td>
#       <td id="T_4ee85_row4_col5" class="data row4 col5" >0.0826</td>
#     </tr>
#     <tr>
#       <th id="T_4ee85_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4ee85_row5_col0" class="data row5 col0" >0.1106</td>
#       <td id="T_4ee85_row5_col1" class="data row5 col1" >0.0218</td>
#       <td id="T_4ee85_row5_col2" class="data row5 col2" >0.1476</td>
#       <td id="T_4ee85_row5_col3" class="data row5 col3" >0.8562</td>
#       <td id="T_4ee85_row5_col4" class="data row5 col4" >0.0604</td>
#       <td id="T_4ee85_row5_col5" class="data row5 col5" >0.0835</td>
#     </tr>
#     <tr>
#       <th id="T_4ee85_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4ee85_row6_col0" class="data row6 col0" >0.1181</td>
#       <td id="T_4ee85_row6_col1" class="data row6 col1" >0.0253</td>
#       <td id="T_4ee85_row6_col2" class="data row6 col2" >0.1591</td>
#       <td id="T_4ee85_row6_col3" class="data row6 col3" >0.8420</td>
#       <td id="T_4ee85_row6_col4" class="data row6 col4" >0.0643</td>
#       <td id="T_4ee85_row6_col5" class="data row6 col5" >0.0883</td>
#     </tr>
#     <tr>
#       <th id="T_4ee85_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4ee85_row7_col0" class="data row7 col0" >0.1203</td>
#       <td id="T_4ee85_row7_col1" class="data row7 col1" >0.0268</td>
#       <td id="T_4ee85_row7_col2" class="data row7 col2" >0.1637</td>
#       <td id="T_4ee85_row7_col3" class="data row7 col3" >0.8421</td>
#       <td id="T_4ee85_row7_col4" class="data row7 col4" >0.0651</td>
#       <td id="T_4ee85_row7_col5" class="data row7 col5" >0.0878</td>
#     </tr>
#     <tr>
#       <th id="T_4ee85_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4ee85_row8_col0" class="data row8 col0" >0.1219</td>
#       <td id="T_4ee85_row8_col1" class="data row8 col1" >0.0256</td>
#       <td id="T_4ee85_row8_col2" class="data row8 col2" >0.1601</td>
#       <td id="T_4ee85_row8_col3" class="data row8 col3" >0.8375</td>
#       <td id="T_4ee85_row8_col4" class="data row8 col4" >0.0648</td>
#       <td id="T_4ee85_row8_col5" class="data row8 col5" >0.0907</td>
#     </tr>
#     <tr>
#       <th id="T_4ee85_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4ee85_row9_col0" class="data row9 col0" >0.1203</td>
#       <td id="T_4ee85_row9_col1" class="data row9 col1" >0.0262</td>
#       <td id="T_4ee85_row9_col2" class="data row9 col2" >0.1617</td>
#       <td id="T_4ee85_row9_col3" class="data row9 col3" >0.8386</td>
#       <td id="T_4ee85_row9_col4" class="data row9 col4" >0.0662</td>
#       <td id="T_4ee85_row9_col5" class="data row9 col5" >0.0918</td>
#     </tr>
#     <tr>
#       <th id="T_4ee85_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_4ee85_row10_col0" class="data row10 col0" >0.1164</td>
#       <td id="T_4ee85_row10_col1" class="data row10 col1" >0.0244</td>
#       <td id="T_4ee85_row10_col2" class="data row10 col2" >0.1561</td>
#       <td id="T_4ee85_row10_col3" class="data row10 col3" >0.8492</td>
#       <td id="T_4ee85_row10_col4" class="data row10 col4" >0.0631</td>
#       <td id="T_4ee85_row10_col5" class="data row10 col5" >0.0866</td>
#     </tr>
#     <tr>
#       <th id="T_4ee85_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_4ee85_row11_col0" class="data row11 col0" >0.0040</td>
#       <td id="T_4ee85_row11_col1" class="data row11 col1" >0.0016</td>
#       <td id="T_4ee85_row11_col2" class="data row11 col2" >0.0053</td>
#       <td id="T_4ee85_row11_col3" class="data row11 col3" >0.0101</td>
#       <td id="T_4ee85_row11_col4" class="data row11 col4" >0.0022</td>
#       <td id="T_4ee85_row11_col5" class="data row11 col5" >0.0033</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
# --- TUNED된 Light GBM의 잔차 PLOT ---
plot_model(tune_lgbm)

# %%
# --- TUNED된 Light GBM의 예측 오류 PLOT ---
plot_model(tune_lgbm, plot = 'error')

# %%
# --- TUNED된 Light GBM의 피처 중요도 PLOT ---
plot_model(tune_lgbm, plot = 'feature')

# %%
# --- 릿지 회귀 모델 생성 ---
ridge = create_model('ridge')
# Out:
# <style type="text/css">
# #T_20a42_row10_col0, #T_20a42_row10_col1, #T_20a42_row10_col2, #T_20a42_row10_col3, #T_20a42_row10_col4, #T_20a42_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_20a42">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20a42_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_20a42_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_20a42_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_20a42_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_20a42_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_20a42_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20a42_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_20a42_row0_col0" class="data row0 col0" >0.1815</td>
#       <td id="T_20a42_row0_col1" class="data row0 col1" >0.0591</td>
#       <td id="T_20a42_row0_col2" class="data row0 col2" >0.2431</td>
#       <td id="T_20a42_row0_col3" class="data row0 col3" >0.6470</td>
#       <td id="T_20a42_row0_col4" class="data row0 col4" >0.0967</td>
#       <td id="T_20a42_row0_col5" class="data row0 col5" >0.1344</td>
#     </tr>
#     <tr>
#       <th id="T_20a42_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_20a42_row1_col0" class="data row1 col0" >0.1846</td>
#       <td id="T_20a42_row1_col1" class="data row1 col1" >0.0593</td>
#       <td id="T_20a42_row1_col2" class="data row1 col2" >0.2434</td>
#       <td id="T_20a42_row1_col3" class="data row1 col3" >0.6568</td>
#       <td id="T_20a42_row1_col4" class="data row1 col4" >0.0966</td>
#       <td id="T_20a42_row1_col5" class="data row1 col5" >0.1353</td>
#     </tr>
#     <tr>
#       <th id="T_20a42_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_20a42_row2_col0" class="data row2 col0" >0.1783</td>
#       <td id="T_20a42_row2_col1" class="data row2 col1" >0.0532</td>
#       <td id="T_20a42_row2_col2" class="data row2 col2" >0.2307</td>
#       <td id="T_20a42_row2_col3" class="data row2 col3" >0.6470</td>
#       <td id="T_20a42_row2_col4" class="data row2 col4" >0.0961</td>
#       <td id="T_20a42_row2_col5" class="data row2 col5" >0.1387</td>
#     </tr>
#     <tr>
#       <th id="T_20a42_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_20a42_row3_col0" class="data row3 col0" >0.1806</td>
#       <td id="T_20a42_row3_col1" class="data row3 col1" >0.0582</td>
#       <td id="T_20a42_row3_col2" class="data row3 col2" >0.2413</td>
#       <td id="T_20a42_row3_col3" class="data row3 col3" >0.6460</td>
#       <td id="T_20a42_row3_col4" class="data row3 col4" >0.0971</td>
#       <td id="T_20a42_row3_col5" class="data row3 col5" >0.1355</td>
#     </tr>
#     <tr>
#       <th id="T_20a42_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_20a42_row4_col0" class="data row4 col0" >0.1798</td>
#       <td id="T_20a42_row4_col1" class="data row4 col1" >0.0548</td>
#       <td id="T_20a42_row4_col2" class="data row4 col2" >0.2341</td>
#       <td id="T_20a42_row4_col3" class="data row4 col3" >0.6651</td>
#       <td id="T_20a42_row4_col4" class="data row4 col4" >0.0942</td>
#       <td id="T_20a42_row4_col5" class="data row4 col5" >0.1342</td>
#     </tr>
#     <tr>
#       <th id="T_20a42_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_20a42_row5_col0" class="data row5 col0" >0.1778</td>
#       <td id="T_20a42_row5_col1" class="data row5 col1" >0.0542</td>
#       <td id="T_20a42_row5_col2" class="data row5 col2" >0.2328</td>
#       <td id="T_20a42_row5_col3" class="data row5 col3" >0.6421</td>
#       <td id="T_20a42_row5_col4" class="data row5 col4" >0.0954</td>
#       <td id="T_20a42_row5_col5" class="data row5 col5" >0.1359</td>
#     </tr>
#     <tr>
#       <th id="T_20a42_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_20a42_row6_col0" class="data row6 col0" >0.1840</td>
#       <td id="T_20a42_row6_col1" class="data row6 col1" >0.0591</td>
#       <td id="T_20a42_row6_col2" class="data row6 col2" >0.2430</td>
#       <td id="T_20a42_row6_col3" class="data row6 col3" >0.6315</td>
#       <td id="T_20a42_row6_col4" class="data row6 col4" >0.0988</td>
#       <td id="T_20a42_row6_col5" class="data row6 col5" >0.1401</td>
#     </tr>
#     <tr>
#       <th id="T_20a42_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_20a42_row7_col0" class="data row7 col0" >0.1893</td>
#       <td id="T_20a42_row7_col1" class="data row7 col1" >0.0661</td>
#       <td id="T_20a42_row7_col2" class="data row7 col2" >0.2571</td>
#       <td id="T_20a42_row7_col3" class="data row7 col3" >0.6105</td>
#       <td id="T_20a42_row7_col4" class="data row7 col4" >0.1015</td>
#       <td id="T_20a42_row7_col5" class="data row7 col5" >0.1386</td>
#     </tr>
#     <tr>
#       <th id="T_20a42_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_20a42_row8_col0" class="data row8 col0" >0.1877</td>
#       <td id="T_20a42_row8_col1" class="data row8 col1" >0.0617</td>
#       <td id="T_20a42_row8_col2" class="data row8 col2" >0.2484</td>
#       <td id="T_20a42_row8_col3" class="data row8 col3" >0.6090</td>
#       <td id="T_20a42_row8_col4" class="data row8 col4" >0.1015</td>
#       <td id="T_20a42_row8_col5" class="data row8 col5" >0.1433</td>
#     </tr>
#     <tr>
#       <th id="T_20a42_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_20a42_row9_col0" class="data row9 col0" >0.1795</td>
#       <td id="T_20a42_row9_col1" class="data row9 col1" >0.0573</td>
#       <td id="T_20a42_row9_col2" class="data row9 col2" >0.2395</td>
#       <td id="T_20a42_row9_col3" class="data row9 col3" >0.6460</td>
#       <td id="T_20a42_row9_col4" class="data row9 col4" >0.0971</td>
#       <td id="T_20a42_row9_col5" class="data row9 col5" >0.1374</td>
#     </tr>
#     <tr>
#       <th id="T_20a42_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_20a42_row10_col0" class="data row10 col0" >0.1823</td>
#       <td id="T_20a42_row10_col1" class="data row10 col1" >0.0583</td>
#       <td id="T_20a42_row10_col2" class="data row10 col2" >0.2413</td>
#       <td id="T_20a42_row10_col3" class="data row10 col3" >0.6401</td>
#       <td id="T_20a42_row10_col4" class="data row10 col4" >0.0975</td>
#       <td id="T_20a42_row10_col5" class="data row10 col5" >0.1373</td>
#     </tr>
#     <tr>
#       <th id="T_20a42_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_20a42_row11_col0" class="data row11 col0" >0.0038</td>
#       <td id="T_20a42_row11_col1" class="data row11 col1" >0.0036</td>
#       <td id="T_20a42_row11_col2" class="data row11 col2" >0.0074</td>
#       <td id="T_20a42_row11_col3" class="data row11 col3" >0.0173</td>
#       <td id="T_20a42_row11_col4" class="data row11 col4" >0.0023</td>
#       <td id="T_20a42_row11_col5" class="data row11 col5" >0.0027</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
# --- 릿지 회귀의 잔차 PLOT---
plot_model(ridge)

# %%
# --- 릿지 회귀의 예측 오류 PLOT---
plot_model(ridge, plot = 'error')

# %%
# --- 릿지 회귀의 피처 중요도 PLOT---
plot_model(ridge, plot = 'feature')

# %%
# --- 릿지 회귀 튜닝 ---
tune_ridge = tune_model(ridge)
# Out:
# <style type="text/css">
# #T_4b069_row10_col0, #T_4b069_row10_col1, #T_4b069_row10_col2, #T_4b069_row10_col3, #T_4b069_row10_col4, #T_4b069_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_4b069">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b069_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_4b069_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_4b069_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_4b069_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_4b069_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_4b069_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b069_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4b069_row0_col0" class="data row0 col0" >0.1814</td>
#       <td id="T_4b069_row0_col1" class="data row0 col1" >0.0591</td>
#       <td id="T_4b069_row0_col2" class="data row0 col2" >0.2430</td>
#       <td id="T_4b069_row0_col3" class="data row0 col3" >0.6472</td>
#       <td id="T_4b069_row0_col4" class="data row0 col4" >0.0967</td>
#       <td id="T_4b069_row0_col5" class="data row0 col5" >0.1342</td>
#     </tr>
#     <tr>
#       <th id="T_4b069_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4b069_row1_col0" class="data row1 col0" >0.1846</td>
#       <td id="T_4b069_row1_col1" class="data row1 col1" >0.0592</td>
#       <td id="T_4b069_row1_col2" class="data row1 col2" >0.2434</td>
#       <td id="T_4b069_row1_col3" class="data row1 col3" >0.6569</td>
#       <td id="T_4b069_row1_col4" class="data row1 col4" >0.0966</td>
#       <td id="T_4b069_row1_col5" class="data row1 col5" >0.1352</td>
#     </tr>
#     <tr>
#       <th id="T_4b069_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4b069_row2_col0" class="data row2 col0" >0.1783</td>
#       <td id="T_4b069_row2_col1" class="data row2 col1" >0.0532</td>
#       <td id="T_4b069_row2_col2" class="data row2 col2" >0.2307</td>
#       <td id="T_4b069_row2_col3" class="data row2 col3" >0.6471</td>
#       <td id="T_4b069_row2_col4" class="data row2 col4" >0.0961</td>
#       <td id="T_4b069_row2_col5" class="data row2 col5" >0.1386</td>
#     </tr>
#     <tr>
#       <th id="T_4b069_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4b069_row3_col0" class="data row3 col0" >0.1806</td>
#       <td id="T_4b069_row3_col1" class="data row3 col1" >0.0583</td>
#       <td id="T_4b069_row3_col2" class="data row3 col2" >0.2414</td>
#       <td id="T_4b069_row3_col3" class="data row3 col3" >0.6458</td>
#       <td id="T_4b069_row3_col4" class="data row3 col4" >0.0971</td>
#       <td id="T_4b069_row3_col5" class="data row3 col5" >0.1353</td>
#     </tr>
#     <tr>
#       <th id="T_4b069_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4b069_row4_col0" class="data row4 col0" >0.1798</td>
#       <td id="T_4b069_row4_col1" class="data row4 col1" >0.0548</td>
#       <td id="T_4b069_row4_col2" class="data row4 col2" >0.2342</td>
#       <td id="T_4b069_row4_col3" class="data row4 col3" >0.6650</td>
#       <td id="T_4b069_row4_col4" class="data row4 col4" >0.0942</td>
#       <td id="T_4b069_row4_col5" class="data row4 col5" >0.1341</td>
#     </tr>
#     <tr>
#       <th id="T_4b069_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4b069_row5_col0" class="data row5 col0" >0.1778</td>
#       <td id="T_4b069_row5_col1" class="data row5 col1" >0.0542</td>
#       <td id="T_4b069_row5_col2" class="data row5 col2" >0.2328</td>
#       <td id="T_4b069_row5_col3" class="data row5 col3" >0.6423</td>
#       <td id="T_4b069_row5_col4" class="data row5 col4" >0.0953</td>
#       <td id="T_4b069_row5_col5" class="data row5 col5" >0.1358</td>
#     </tr>
#     <tr>
#       <th id="T_4b069_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4b069_row6_col0" class="data row6 col0" >0.1839</td>
#       <td id="T_4b069_row6_col1" class="data row6 col1" >0.0590</td>
#       <td id="T_4b069_row6_col2" class="data row6 col2" >0.2430</td>
#       <td id="T_4b069_row6_col3" class="data row6 col3" >0.6316</td>
#       <td id="T_4b069_row6_col4" class="data row6 col4" >0.0988</td>
#       <td id="T_4b069_row6_col5" class="data row6 col5" >0.1399</td>
#     </tr>
#     <tr>
#       <th id="T_4b069_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4b069_row7_col0" class="data row7 col0" >0.1892</td>
#       <td id="T_4b069_row7_col1" class="data row7 col1" >0.0661</td>
#       <td id="T_4b069_row7_col2" class="data row7 col2" >0.2571</td>
#       <td id="T_4b069_row7_col3" class="data row7 col3" >0.6104</td>
#       <td id="T_4b069_row7_col4" class="data row7 col4" >0.1015</td>
#       <td id="T_4b069_row7_col5" class="data row7 col5" >0.1385</td>
#     </tr>
#     <tr>
#       <th id="T_4b069_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4b069_row8_col0" class="data row8 col0" >0.1878</td>
#       <td id="T_4b069_row8_col1" class="data row8 col1" >0.0617</td>
#       <td id="T_4b069_row8_col2" class="data row8 col2" >0.2484</td>
#       <td id="T_4b069_row8_col3" class="data row8 col3" >0.6090</td>
#       <td id="T_4b069_row8_col4" class="data row8 col4" >0.1015</td>
#       <td id="T_4b069_row8_col5" class="data row8 col5" >0.1432</td>
#     </tr>
#     <tr>
#       <th id="T_4b069_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4b069_row9_col0" class="data row9 col0" >0.1796</td>
#       <td id="T_4b069_row9_col1" class="data row9 col1" >0.0574</td>
#       <td id="T_4b069_row9_col2" class="data row9 col2" >0.2395</td>
#       <td id="T_4b069_row9_col3" class="data row9 col3" >0.6460</td>
#       <td id="T_4b069_row9_col4" class="data row9 col4" >0.0971</td>
#       <td id="T_4b069_row9_col5" class="data row9 col5" >0.1373</td>
#     </tr>
#     <tr>
#       <th id="T_4b069_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_4b069_row10_col0" class="data row10 col0" >0.1823</td>
#       <td id="T_4b069_row10_col1" class="data row10 col1" >0.0583</td>
#       <td id="T_4b069_row10_col2" class="data row10 col2" >0.2413</td>
#       <td id="T_4b069_row10_col3" class="data row10 col3" >0.6401</td>
#       <td id="T_4b069_row10_col4" class="data row10 col4" >0.0975</td>
#       <td id="T_4b069_row10_col5" class="data row10 col5" >0.1372</td>
#     </tr>
#     <tr>
#       <th id="T_4b069_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_4b069_row11_col0" class="data row11 col0" >0.0037</td>
#       <td id="T_4b069_row11_col1" class="data row11 col1" >0.0036</td>
#       <td id="T_4b069_row11_col2" class="data row11 col2" >0.0074</td>
#       <td id="T_4b069_row11_col3" class="data row11 col3" >0.0173</td>
#       <td id="T_4b069_row11_col4" class="data row11 col4" >0.0023</td>
#       <td id="T_4b069_row11_col5" class="data row11 col5" >0.0027</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
# --- TUNED된 릿지 회귀의 잔차 PLOT ---
plot_model(tune_ridge)

# %%
# --- TUNED된 릿지 회귀의 예측 오류 PLOT ---
plot_model(tune_ridge, plot = 'error')

# %%
# --- TUNED된 릿지 회귀의 피처 중요도 PLOT ---
plot_model(tune_ridge, plot = 'feature')

# %%
# --- Prediction using Best Model ---
predict_model(best_models)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c9ab9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9ab9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c9ab9_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_c9ab9_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_c9ab9_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_c9ab9_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_c9ab9_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_c9ab9_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9ab9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c9ab9_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_c9ab9_row0_col1" class="data row0 col1" >0.0734</td>
#       <td id="T_c9ab9_row0_col2" class="data row0 col2" >0.0122</td>
#       <td id="T_c9ab9_row0_col3" class="data row0 col3" >0.1106</td>
#       <td id="T_c9ab9_row0_col4" class="data row0 col4" >0.9244</td>
#       <td id="T_c9ab9_row0_col5" class="data row0 col5" >0.0440</td>
#       <td id="T_c9ab9_row0_col6" class="data row0 col6" >0.0540</td>
#     </tr>
#   </tbody>
# </table>
#        Unnamed: 0       Date  Total Volume          4046          4225  \
# 5078           34 2016-05-01  8.580374e+05  9.113613e+04  2.710051e+05
# 10697          11 2015-10-11  8.749600e+03  6.000000e+00  6.835000e+01
# 15569          33 2017-05-14  1.437912e+05  3.379520e+03  7.303243e+04
# 2001           25 2015-07-05  2.875719e+05  9.488031e+04  1.180226e+05
# 15780          32 2017-05-21  8.759490e+03  7.682000e+01  1.259860e+03
# ...           ...        ...           ...           ...           ...
# 3639           51 2016-01-03  4.065584e+06  6.046972e+05  2.200075e+06
# 326            14 2015-09-20  4.759791e+06  1.702966e+06  2.230694e+06
# 17177          51 2017-01-08  1.044249e+05  2.621250e+04  6.181320e+03
# 13098          21 2016-07-31  1.153139e+05  1.465426e+04  2.827826e+04
# 1898           26 2015-06-28  5.081741e+05  1.967651e+05  2.231285e+05
#
#                 4770     Total Bags     Small Bags     Large Bags  \
# 5078    11463.750000  484432.531250  458041.093750   25900.730469
# 10697       0.000000    8675.250000    8675.250000       0.000000
# 15569       0.000000   67379.257812   29130.710938   38248.550781
# 2001    15212.240234   59456.820312   58905.710938     551.109985
# 15780       0.000000    7422.810059    2038.260010    5384.549805
# ...              ...            ...            ...            ...
# 3639   543717.875000  717093.500000  438279.968750  147920.687500
# 326    273922.375000  552209.750000  529779.375000   17303.910156
# 17177       0.000000   72031.062500   69782.273438    2248.790039
# 13098       1.600000   72379.726562   70166.726562    2213.000000
# 1898    21601.640625   66678.859375   66557.460938      98.419998
#
#          XLarge Bags          type  year              region  month  \
# 5078      490.709991  conventional  2016             Seattle      5
# 10697       0.000000       organic  2015  NorthernNewEngland     10
# 15569       0.000000       organic  2017          GreatLakes      5
# 2001        0.000000  conventional  2015     RichmondNorfolk      7
# 15780       0.000000       organic  2017        Indianapolis      5
# ...              ...           ...   ...                 ...    ...
# 3639   130892.796875  conventional  2016          GreatLakes      1
# 326      5126.490234  conventional  2015          California      9
# 17177       0.000000       organic  2017        SouthCentral      1
# 13098       0.000000       organic  2016          LosAngeles      7
# 1898       22.980000  conventional  2015            Portland      6
#
#        AveragePrice  prediction_label
# 5078           0.82            0.8442
# 10697          1.61            1.6179
# 15569          1.68            1.5701
# 2001           1.01            1.0194
# 15780          0.92            1.4351
# ...             ...               ...
# 3639           0.92            0.9325
# 326            1.14            1.1133
# 17177          1.10            1.0826
# 13098          1.21            1.2988
# 1898           1.16            1.1183
#
# [3650 rows x 16 columns]

# %%
# --- 랜덤 포레스트 모델 prediction ---
predict_model(rf)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d65b4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d65b4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d65b4_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_d65b4_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_d65b4_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_d65b4_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_d65b4_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_d65b4_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d65b4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d65b4_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_d65b4_row0_col1" class="data row0 col1" >0.0798</td>
#       <td id="T_d65b4_row0_col2" class="data row0 col2" >0.0137</td>
#       <td id="T_d65b4_row0_col3" class="data row0 col3" >0.1172</td>
#       <td id="T_d65b4_row0_col4" class="data row0 col4" >0.9151</td>
#       <td id="T_d65b4_row0_col5" class="data row0 col5" >0.0466</td>
#       <td id="T_d65b4_row0_col6" class="data row0 col6" >0.0586</td>
#     </tr>
#   </tbody>
# </table>
#        Unnamed: 0       Date  Total Volume          4046          4225  \
# 5078           34 2016-05-01  8.580374e+05  9.113613e+04  2.710051e+05
# 10697          11 2015-10-11  8.749600e+03  6.000000e+00  6.835000e+01
# 15569          33 2017-05-14  1.437912e+05  3.379520e+03  7.303243e+04
# 2001           25 2015-07-05  2.875719e+05  9.488031e+04  1.180226e+05
# 15780          32 2017-05-21  8.759490e+03  7.682000e+01  1.259860e+03
# ...           ...        ...           ...           ...           ...
# 3639           51 2016-01-03  4.065584e+06  6.046972e+05  2.200075e+06
# 326            14 2015-09-20  4.759791e+06  1.702966e+06  2.230694e+06
# 17177          51 2017-01-08  1.044249e+05  2.621250e+04  6.181320e+03
# 13098          21 2016-07-31  1.153139e+05  1.465426e+04  2.827826e+04
# 1898           26 2015-06-28  5.081741e+05  1.967651e+05  2.231285e+05
#
#                 4770     Total Bags     Small Bags     Large Bags  \
# 5078    11463.750000  484432.531250  458041.093750   25900.730469
# 10697       0.000000    8675.250000    8675.250000       0.000000
# 15569       0.000000   67379.257812   29130.710938   38248.550781
# 2001    15212.240234   59456.820312   58905.710938     551.109985
# 15780       0.000000    7422.810059    2038.260010    5384.549805
# ...              ...            ...            ...            ...
# 3639   543717.875000  717093.500000  438279.968750  147920.687500
# 326    273922.375000  552209.750000  529779.375000   17303.910156
# 17177       0.000000   72031.062500   69782.273438    2248.790039
# 13098       1.600000   72379.726562   70166.726562    2213.000000
# 1898    21601.640625   66678.859375   66557.460938      98.419998
#
#          XLarge Bags          type  year              region  month  \
# 5078      490.709991  conventional  2016             Seattle      5
# 10697       0.000000       organic  2015  NorthernNewEngland     10
# 15569       0.000000       organic  2017          GreatLakes      5
# 2001        0.000000  conventional  2015     RichmondNorfolk      7
# 15780       0.000000       organic  2017        Indianapolis      5
# ...              ...           ...   ...                 ...    ...
# 3639   130892.796875  conventional  2016          GreatLakes      1
# 326      5126.490234  conventional  2015          California      9
# 17177       0.000000       organic  2017        SouthCentral      1
# 13098       0.000000       organic  2016          LosAngeles      7
# 1898       22.980000  conventional  2015            Portland      6
#
#        AveragePrice  prediction_label
# 5078           0.82            0.8497
# 10697          1.61            1.6042
# 15569          1.68            1.5587
# 2001           1.01            1.0627
# 15780          0.92            1.2473
# ...             ...               ...
# 3639           0.92            0.9434
# 326            1.14            1.0893
# 17177          1.10            1.1905
# 13098          1.21            1.3179
# 1898           1.16            1.1071
#
# [3650 rows x 16 columns]

# %%
# --- Light Gradient Boosting 모델 prediction ---
predict_model(lgbm)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1a02a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a02a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1a02a_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_1a02a_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_1a02a_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_1a02a_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_1a02a_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_1a02a_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a02a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1a02a_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_1a02a_row0_col1" class="data row0 col1" >0.1018</td>
#       <td id="T_1a02a_row0_col2" class="data row0 col2" >0.0192</td>
#       <td id="T_1a02a_row0_col3" class="data row0 col3" >0.1387</td>
#       <td id="T_1a02a_row0_col4" class="data row0 col4" >0.8811</td>
#       <td id="T_1a02a_row0_col5" class="data row0 col5" >0.0552</td>
#       <td id="T_1a02a_row0_col6" class="data row0 col6" >0.0746</td>
#     </tr>
#   </tbody>
# </table>
#        Unnamed: 0       Date  Total Volume          4046          4225  \
# 5078           34 2016-05-01  8.580374e+05  9.113613e+04  2.710051e+05
# 10697          11 2015-10-11  8.749600e+03  6.000000e+00  6.835000e+01
# 15569          33 2017-05-14  1.437912e+05  3.379520e+03  7.303243e+04
# 2001           25 2015-07-05  2.875719e+05  9.488031e+04  1.180226e+05
# 15780          32 2017-05-21  8.759490e+03  7.682000e+01  1.259860e+03
# ...           ...        ...           ...           ...           ...
# 3639           51 2016-01-03  4.065584e+06  6.046972e+05  2.200075e+06
# 326            14 2015-09-20  4.759791e+06  1.702966e+06  2.230694e+06
# 17177          51 2017-01-08  1.044249e+05  2.621250e+04  6.181320e+03
# 13098          21 2016-07-31  1.153139e+05  1.465426e+04  2.827826e+04
# 1898           26 2015-06-28  5.081741e+05  1.967651e+05  2.231285e+05
#
#                 4770     Total Bags     Small Bags     Large Bags  \
# 5078    11463.750000  484432.531250  458041.093750   25900.730469
# 10697       0.000000    8675.250000    8675.250000       0.000000
# 15569       0.000000   67379.257812   29130.710938   38248.550781
# 2001    15212.240234   59456.820312   58905.710938     551.109985
# 15780       0.000000    7422.810059    2038.260010    5384.549805
# ...              ...            ...            ...            ...
# 3639   543717.875000  717093.500000  438279.968750  147920.687500
# 326    273922.375000  552209.750000  529779.375000   17303.910156
# 17177       0.000000   72031.062500   69782.273438    2248.790039
# 13098       1.600000   72379.726562   70166.726562    2213.000000
# 1898    21601.640625   66678.859375   66557.460938      98.419998
#
#          XLarge Bags          type  year              region  month  \
# 5078      490.709991  conventional  2016             Seattle      5
# 10697       0.000000       organic  2015  NorthernNewEngland     10
# 15569       0.000000       organic  2017          GreatLakes      5
# 2001        0.000000  conventional  2015     RichmondNorfolk      7
# 15780       0.000000       organic  2017        Indianapolis      5
# ...              ...           ...   ...                 ...    ...
# 3639   130892.796875  conventional  2016          GreatLakes      1
# 326      5126.490234  conventional  2015          California      9
# 17177       0.000000       organic  2017        SouthCentral      1
# 13098       0.000000       organic  2016          LosAngeles      7
# 1898       22.980000  conventional  2015            Portland      6
#
#        AveragePrice  prediction_label
# 5078           0.82          0.857325
# 10697          1.61          1.562000
# 15569          1.68          1.477120
# 2001           1.01          1.057732
# 15780          0.92          1.232317
# ...             ...               ...
# 3639           0.92          0.949554
# 326            1.14          1.059290
# 17177          1.10          1.124681
# 13098          1.21          1.481890
# 1898           1.16          1.062897
#
# [3650 rows x 16 columns]

# %%
# --- 릿지 회귀 모델 prediction ---
predict_model(ridge)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2a549">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a549_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2a549_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_2a549_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_2a549_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_2a549_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_2a549_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_2a549_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a549_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2a549_row0_col0" class="data row0 col0" >Ridge Regression</td>
#       <td id="T_2a549_row0_col1" class="data row0 col1" >0.1822</td>
#       <td id="T_2a549_row0_col2" class="data row0 col2" >0.0585</td>
#       <td id="T_2a549_row0_col3" class="data row0 col3" >0.2419</td>
#       <td id="T_2a549_row0_col4" class="data row0 col4" >0.6384</td>
#       <td id="T_2a549_row0_col5" class="data row0 col5" >0.0967</td>
#       <td id="T_2a549_row0_col6" class="data row0 col6" >0.1350</td>
#     </tr>
#   </tbody>
# </table>
#        Unnamed: 0       Date  Total Volume          4046          4225  \
# 5078           34 2016-05-01  8.580374e+05  9.113613e+04  2.710051e+05
# 10697          11 2015-10-11  8.749600e+03  6.000000e+00  6.835000e+01
# 15569          33 2017-05-14  1.437912e+05  3.379520e+03  7.303243e+04
# 2001           25 2015-07-05  2.875719e+05  9.488031e+04  1.180226e+05
# 15780          32 2017-05-21  8.759490e+03  7.682000e+01  1.259860e+03
# ...           ...        ...           ...           ...           ...
# 3639           51 2016-01-03  4.065584e+06  6.046972e+05  2.200075e+06
# 326            14 2015-09-20  4.759791e+06  1.702966e+06  2.230694e+06
# 17177          51 2017-01-08  1.044249e+05  2.621250e+04  6.181320e+03
# 13098          21 2016-07-31  1.153139e+05  1.465426e+04  2.827826e+04
# 1898           26 2015-06-28  5.081741e+05  1.967651e+05  2.231285e+05
#
#                 4770     Total Bags     Small Bags     Large Bags  \
# 5078    11463.750000  484432.531250  458041.093750   25900.730469
# 10697       0.000000    8675.250000    8675.250000       0.000000
# 15569       0.000000   67379.257812   29130.710938   38248.550781
# 2001    15212.240234   59456.820312   58905.710938     551.109985
# 15780       0.000000    7422.810059    2038.260010    5384.549805
# ...              ...            ...            ...            ...
# 3639   543717.875000  717093.500000  438279.968750  147920.687500
# 326    273922.375000  552209.750000  529779.375000   17303.910156
# 17177       0.000000   72031.062500   69782.273438    2248.790039
# 13098       1.600000   72379.726562   70166.726562    2213.000000
# 1898    21601.640625   66678.859375   66557.460938      98.419998
#
#          XLarge Bags          type  year              region  month  \
# 5078      490.709991  conventional  2016             Seattle      5
# 10697       0.000000       organic  2015  NorthernNewEngland     10
# 15569       0.000000       organic  2017          GreatLakes      5
# 2001        0.000000  conventional  2015     RichmondNorfolk      7
# 15780       0.000000       organic  2017        Indianapolis      5
# ...              ...           ...   ...                 ...    ...
# 3639   130892.796875  conventional  2016          GreatLakes      1
# 326      5126.490234  conventional  2015          California      9
# 17177       0.000000       organic  2017        SouthCentral      1
# 13098       0.000000       organic  2016          LosAngeles      7
# 1898       22.980000  conventional  2015            Portland      6
#
#        AveragePrice  prediction_label
# 5078           0.82          1.065406
# 10697          1.61          1.858401
# 15569          1.68          1.652461
# 2001           1.01          1.048688
# 15780          0.92          1.628299
# ...             ...               ...
# 3639           0.92          1.043863
# 326            1.14          1.308514
# 17177          1.10          1.339332
# 13098          1.21          1.450807
# 1898           1.16          1.046973
#
# [3650 rows x 16 columns]

# %%
# --- 최종 Best Model ---
final_best = finalize_model(best_models)

# --- 최종 Best Model Parameters for Deployment ---
plot_model(best_models, plot='parameter')
# Out:
#                              Parameters
# bootstrap                         False
# ccp_alpha                           0.0
# criterion                 squared_error
# max_depth                          None
# max_features                       auto
# max_leaf_nodes                     None
# max_samples                        None
# min_impurity_decrease               0.0
# min_samples_leaf                      1
# min_samples_split                     2
# min_weight_fraction_leaf            0.0
# n_estimators                        100
# n_jobs                               -1
# oob_score                         False
# random_state                        123
# verbose                               0
# warm_start                        False

# %%
# --- 최종 모델을 이용한 prediction ---
predict_model(final_best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_92f38">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92f38_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_92f38_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_92f38_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_92f38_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_92f38_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_92f38_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_92f38_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92f38_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_92f38_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_92f38_row0_col1" class="data row0 col1" >0.2359</td>
#       <td id="T_92f38_row0_col2" class="data row0 col2" >0.1352</td>
#       <td id="T_92f38_row0_col3" class="data row0 col3" >0.3677</td>
#       <td id="T_92f38_row0_col4" class="data row0 col4" >0.1649</td>
#       <td id="T_92f38_row0_col5" class="data row0 col5" >0.1445</td>
#       <td id="T_92f38_row0_col6" class="data row0 col6" >0.1401</td>
#     </tr>
#   </tbody>
# </table>
#        Unnamed: 0       Date  Total Volume          4046          4225  \
# 5078           34 2016-05-01  8.580374e+05  9.113613e+04  2.710051e+05
# 10697          11 2015-10-11  8.749600e+03  6.000000e+00  6.835000e+01
# 15569          33 2017-05-14  1.437912e+05  3.379520e+03  7.303243e+04
# 2001           25 2015-07-05  2.875719e+05  9.488031e+04  1.180226e+05
# 15780          32 2017-05-21  8.759490e+03  7.682000e+01  1.259860e+03
# ...           ...        ...           ...           ...           ...
# 3639           51 2016-01-03  4.065584e+06  6.046972e+05  2.200075e+06
# 326            14 2015-09-20  4.759791e+06  1.702966e+06  2.230694e+06
# 17177          51 2017-01-08  1.044249e+05  2.621250e+04  6.181320e+03
# 13098          21 2016-07-31  1.153139e+05  1.465426e+04  2.827826e+04
# 1898           26 2015-06-28  5.081741e+05  1.967651e+05  2.231285e+05
#
#                 4770     Total Bags     Small Bags     Large Bags  \
# 5078    11463.750000  484432.531250  458041.093750   25900.730469
# 10697       0.000000    8675.250000    8675.250000       0.000000
# 15569       0.000000   67379.257812   29130.710938   38248.550781
# 2001    15212.240234   59456.820312   58905.710938     551.109985
# 15780       0.000000    7422.810059    2038.260010    5384.549805
# ...              ...            ...            ...            ...
# 3639   543717.875000  717093.500000  438279.968750  147920.687500
# 326    273922.375000  552209.750000  529779.375000   17303.910156
# 17177       0.000000   72031.062500   69782.273438    2248.790039
# 13098       1.600000   72379.726562   70166.726562    2213.000000
# 1898    21601.640625   66678.859375   66557.460938      98.419998
#
#          XLarge Bags          type  year              region  month  \
# 5078      490.709991  conventional  2016             Seattle      5
# 10697       0.000000       organic  2015  NorthernNewEngland     10
# 15569       0.000000       organic  2017          GreatLakes      5
# 2001        0.000000  conventional  2015     RichmondNorfolk      7
# 15780       0.000000       organic  2017        Indianapolis      5
# ...              ...           ...   ...                 ...    ...
# 3639   130892.796875  conventional  2016          GreatLakes      1
# 326      5126.490234  conventional  2015          California      9
# 17177       0.000000       organic  2017        SouthCentral      1
# 13098       0.000000       organic  2016          LosAngeles      7
# 1898       22.980000  conventional  2015            Portland      6
#
#        AveragePrice  prediction_label
# 5078           0.82            0.8678
# 10697          1.61            1.1751
# 15569          1.68            1.1492
# 2001           1.01            1.0165
# 15780          0.92            1.2697
# ...             ...               ...
# 3639           0.92            0.9092
# 326            1.14            1.1134
# 17177          1.10            0.8160
# 13098          1.21            1.1026
# 1898           1.16            1.0171
#
# [3650 rows x 16 columns]
